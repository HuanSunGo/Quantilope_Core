# %% [markdown]
# # An overview on KPIs
#
# This notebook provides an overview on the KPIs of all data sets and how they relate to each other.

# %%
import pandas as pd
import seaborn as sns

# %%
brands = ["Adidas", "Converse", "New Balance", "Nike","Reebok"]
sentiments = ["negative", "neutral", "positive"]

# %% [markdown]
# ## The data sets
#
# The data sets retrieved from each source should look similar to the stubs presented below.

# %% [markdown]
# Share of voice data source: [Link](https://github.com/HuanSunGo/Quantilope_Core/blob/main/src/tweet_analysis/twitter_frances/share_of_voice_franyang_nov10.ipynb) <br>
# Activities per tweet data source: [Link](https://github.com/HuanSunGo/Quantilope_Core/blob/main/src/tweet_analysis/twitter_frances/activities_per_tweet_franyang_nov10.ipynb)

# %% [markdown]
# ### Twitter:

# %%
# Add also the other KPIs for activities per tweet and share of voice as columns to the data set.
twitter_stub = pd.DataFrame(index=brands, columns=[f"perc_{sentiment}" for sentiment in sentiments])

"""Twitter Dataset"""

# please fill in the sentiment percent below 
twitter_stub["perc_negative"] = [0.12, 0.17, 0.09, 0.13, 0.07]
twitter_stub["perc_neutral"] = [0.67, 0.61, 0.64, 0.66, 0.79]
twitter_stub["perc_positive"] = [0.20, 0.22, 0.27, 0.21, 0.14]


# share of voice
twitter_stub['share_of_voice'] = [0.192406, 0.076869, 0.055327, 0.654862, 0.020535]

# activities per tweet 
twitter_stub['retweets_mean'] = [0.711236, 0.462702, 0.826331, 0.563720, 0.320755]
twitter_stub['replies_mean'] = [0.802255, 0.684476, 0.705882, 0.644066, 0.483019]
twitter_stub['likes_mean'] = [6.503826, 6.407258, 7.292717, 6.964975, 5.664151]
twitter_stub['quote_count_mean'] = [0.161498, 0.100806, 0.149860, 0.114898, 0.064151]

twitter_stub
# Out:
#              perc_negative  perc_neutral  perc_positive  share_of_voice  \
# Adidas                0.12          0.67           0.20        0.192406
# Converse              0.17          0.61           0.22        0.076869
# New Balance           0.09          0.64           0.27        0.055327
# Nike                  0.13          0.66           0.21        0.654862
# Reebok                0.07          0.79           0.14        0.020535
#
#              retweets_mean  replies_mean  likes_mean  quote_count_mean
# Adidas            0.711236      0.802255    6.503826          0.161498
# Converse          0.462702      0.684476    6.407258          0.100806
# New Balance       0.826331      0.705882    7.292717          0.149860
# Nike              0.563720      0.644066    6.964975          0.114898
# Reebok            0.320755      0.483019    5.664151          0.064151

# %% [markdown]
# ## Total Survey Sample

# %% [markdown]
# #### Adding more KPI to survey

# %%
# load the additional KPIs 
df_kpi_tot = pd.read_csv("total_brand_KPI.csv")

df_kpi_tot = df_kpi.rename(columns={'Unnamed: 0': 'brands'})
df_kpi_tot
# Out:
#         brands  brand_aware  brand_consideration  brand_purchase  \
# 0       Adidas         0.92                 0.60            0.56
# 1     Converse         0.77                 0.35            0.36
# 2  New Balance         0.79                 0.49            0.44
# 3         Nike         0.94                 0.68            0.71
# 4       Reebok         0.81                 0.81            0.35
#
#    brand_preference
# 0              0.56
# 1              0.36
# 2              0.44
# 3              0.71
# 4              0.35

# %%
# roberta sentiment scores on total survey

survey_tot_stub = pd.DataFrame(columns=[f"perc_{sentiment}" for sentiment in sentiments])

survey_tot_stub["perc_positive"] = [0.56, 0.45, 0.56, 0.56, 0.46]
survey_tot_stub["perc_neutral"] = [0.33, 0.42, 0.34, 0.27, 0.36]
survey_tot_stub["perc_negative"] = [0.11, 0.13, 0.10, 0.16, 0.18]
survey_tot_stub['brands'] = brands
survey_tot_stub
# Out:
#    perc_negative  perc_neutral  perc_positive       brands
# 0           0.11          0.33           0.56       Adidas
# 1           0.13          0.42           0.45     Converse
# 2           0.10          0.34           0.56  New Balance
# 3           0.16          0.27           0.56         Nike
# 4           0.18          0.36           0.46       Reebok

# %%
# final total survey dataframe for correlation computation 
survey_tot = pd.merge(survey_tot_stub,df_kpi_tot, on='brands')
survey_tot = survey_tot.set_index('brands')
survey_tot
# Out:
#              perc_negative  perc_neutral  perc_positive  brand_aware  \
# brands
# Adidas                0.11          0.33           0.56         0.92
# Converse              0.13          0.42           0.45         0.77
# New Balance           0.10          0.34           0.56         0.79
# Nike                  0.16          0.27           0.56         0.94
# Reebok                0.18          0.36           0.46         0.81
#
#              brand_consideration  brand_purchase  brand_preference
# brands
# Adidas                      0.60            0.56              0.56
# Converse                    0.35            0.36              0.36
# New Balance                 0.49            0.44              0.44
# Nike                        0.68            0.71              0.71
# Reebok                      0.81            0.35              0.35

# %% [markdown]
# ## Survey Sub-sample

# %%
'''
This part is for the subsample dataset. (Twitter users)
'''

survey_twitter_savy_stub = pd.DataFrame(index=brands, columns=[f"perc_{sentiment}" for sentiment in sentiments])

survey_twitter_savy_stub["perc_positive"] = [0.65, 0.53, 0.63, 0.69, 0.57]
survey_twitter_savy_stub["perc_neutral"] = [0.28, 0.36,  0.26,0.23, 0.30]
survey_twitter_savy_stub["perc_negative"] = [0.07, 0.10, 0.10, 0.08, 0.12]
survey_twitter_savy_stub['brands'] =brands
survey_twitter_savy_stub
# Out:
#              perc_negative  perc_neutral  perc_positive       brands
# Adidas                0.07          0.28           0.65       Adidas
# Converse              0.10          0.36           0.53     Converse
# New Balance           0.10          0.26           0.63  New Balance
# Nike                  0.08          0.23           0.69         Nike
# Reebok                0.12          0.30           0.57       Reebok

# %%
# load additional KPIs for the subsample
subsample_kpi = pd.read_csv("subsample_brand_KPI_nov17.csv")
subsample_kpi = subsample_kpi.rename(columns={'Unnamed: 0': 'brands'})
subsample_kpi
# Out:
#         brands  brand_aware  brand_consideration  brand_purchase  \
# 0       Adidas         0.92                 0.68            0.65
# 1     Converse         0.69                 0.41            0.36
# 2  New Balance         0.72                 0.46            0.40
# 3         Nike         0.93                 0.76            0.76
# 4       Reebok         0.75                 0.39            0.36
#
#    brand_preference
# 0              0.33
# 1              0.33
# 2              0.23
# 3              0.42
# 4              0.14

# %%
# final subsample survey dataframe for correlation computation 
survey_subsample = pd.merge(survey_twitter_savy_stub,subsample_kpi, on='brands')
survey_subsample = survey_subsample.set_index('brands')
survey_subsample
# Out:
#              perc_negative  perc_neutral  perc_positive  brand_aware  \
# brands
# Adidas                0.07          0.28           0.65         0.92
# Converse              0.10          0.36           0.53         0.69
# New Balance           0.10          0.26           0.63         0.72
# Nike                  0.08          0.23           0.69         0.93
# Reebok                0.12          0.30           0.57         0.75
#
#              brand_consideration  brand_purchase  brand_preference
# brands
# Adidas                      0.68            0.65              0.33
# Converse                    0.41            0.36              0.33
# New Balance                 0.46            0.40              0.23
# Nike                        0.76            0.76              0.42
# Reebok                      0.39            0.36              0.14

# %% [markdown]
# # Within-data correlation
#
# Here, we want to see how KPIs within a data set are correlated with each other. For that, we first rank the data. Let us take the twitter data as an example.

# %% [markdown]
# ## Twitter

# %%
twitter_ranked = twitter_stub.rank(axis="index", ascending=False)
twitter_ranked
# Out:
#              perc_negative  perc_neutral  perc_positive  share_of_voice  \
# Adidas                 3.0           2.0            4.0             2.0
# Converse               1.0           5.0            2.0             3.0
# New Balance            4.0           4.0            1.0             4.0
# Nike                   2.0           3.0            3.0             1.0
# Reebok                 5.0           1.0            5.0             5.0
#
#              retweets_mean  replies_mean  likes_mean  quote_count_mean
# Adidas                 2.0           1.0         3.0               1.0
# Converse               4.0           3.0         4.0               4.0
# New Balance            1.0           2.0         1.0               2.0
# Nike                   3.0           4.0         2.0               3.0
# Reebok                 5.0           5.0         5.0               5.0

# %% [markdown]
# ## Survey (sub-sample)

# %%
survey_sub_ranked = survey_subsample.rank(axis="index", ascending=False)
df1 = survey_sub_ranked
survey_sub_ranked
# Out:
#              perc_negative  perc_neutral  perc_positive  brand_aware  \
# brands
# Adidas                 5.0           3.0            2.0          2.0
# Converse               2.5           1.0            5.0          5.0
# New Balance            2.5           4.0            3.0          4.0
# Nike                   4.0           5.0            1.0          1.0
# Reebok                 1.0           2.0            4.0          3.0
#
#              brand_consideration  brand_purchase  brand_preference
# brands
# Adidas                       2.0             2.0               2.5
# Converse                     4.0             4.5               2.5
# New Balance                  3.0             3.0               4.0
# Nike                         1.0             1.0               1.0
# Reebok                       5.0             4.5               5.0

# %% [markdown]
# ## Survey (total)

# %%
survey_tot_ranked = survey_tot.rank(axis="index", ascending=False)
df2 = survey_tot_ranked
survey_tot_ranked
# Out:
#              perc_negative  perc_neutral  perc_positive  brand_aware  \
# brands
# Adidas                 4.0           4.0            2.0          2.0
# Converse               3.0           1.0            5.0          5.0
# New Balance            5.0           3.0            2.0          4.0
# Nike                   2.0           5.0            2.0          1.0
# Reebok                 1.0           2.0            4.0          3.0
#
#              brand_consideration  brand_purchase  brand_preference
# brands
# Adidas                       3.0             2.0               2.0
# Converse                     5.0             4.0               4.0
# New Balance                  4.0             3.0               3.0
# Nike                         2.0             1.0               1.0
# Reebok                       1.0             5.0               5.0

# %% [markdown]
# Now, that all the KPIs are ranked, let's calculate Kendall's tau for each combination of KPIs.

# %% [markdown]
# ## Kendall's Tau Calculation

# %%
# Twitter 

cross_correlations_twitter = twitter_ranked.corr(method="kendall")
cross_correlations_twitter
# Out:
#                   perc_negative  perc_neutral  perc_positive  share_of_voice  \
# perc_negative               1.0          -0.6            0.4             0.6
# perc_neutral               -0.6           1.0           -0.8            -0.2
# perc_positive               0.4          -0.8            1.0             0.0
# share_of_voice              0.6          -0.2            0.0             1.0
# retweets_mean              -0.2          -0.2            0.4             0.2
# replies_mean                0.2          -0.2            0.4             0.2
# likes_mean                  0.0          -0.4            0.6             0.4
# quote_count_mean            0.0           0.0            0.2             0.4
#
#                   retweets_mean  replies_mean  likes_mean  quote_count_mean
# perc_negative              -0.2           0.2         0.0               0.0
# perc_neutral               -0.2          -0.2        -0.4               0.0
# perc_positive               0.4           0.4         0.6               0.2
# share_of_voice              0.2           0.2         0.4               0.4
# retweets_mean               1.0           0.6         0.8               0.8
# replies_mean                0.6           1.0         0.4               0.8
# likes_mean                  0.8           0.4         1.0               0.6
# quote_count_mean            0.8           0.8         0.6               1.0

# %%
# Survey Sub-sample
cross_correlations_survey_sub1 = survey_sub_ranked.corr(method = "kendall")
cross_correlations_survey_sub1
# Out:
#                      perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative             1.000000      0.316228      -0.527046    -0.316228
# perc_neutral              0.316228      1.000000      -0.800000    -0.600000
# perc_positive            -0.527046     -0.800000       1.000000     0.800000
# brand_aware              -0.316228     -0.600000       0.800000     1.000000
# brand_consideration      -0.737865     -0.600000       0.800000     0.600000
# brand_purchase           -0.666667     -0.737865       0.948683     0.737865
# brand_preference         -0.666667     -0.316228       0.527046     0.316228
#
#                      brand_consideration  brand_purchase  brand_preference
# perc_negative                  -0.737865       -0.666667         -0.666667
# perc_neutral                   -0.600000       -0.737865         -0.316228
# perc_positive                   0.800000        0.948683          0.527046
# brand_aware                     0.600000        0.737865          0.316228
# brand_consideration             1.000000        0.948683          0.737865
# brand_purchase                  0.948683        1.000000          0.666667
# brand_preference                0.737865        0.666667          1.000000

# %%
# Survey Total
cross_correlations_survey_tot1 = survey_tot_ranked.corr(method="kendall")
cross_correlations_survey_tot1
# Out:
#                      perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative             1.000000       0.00000      -0.358569     0.200000
# perc_neutral              0.000000       1.00000      -0.836660    -0.800000
# perc_positive            -0.358569      -0.83666       1.000000     0.597614
# brand_aware               0.200000      -0.80000       0.597614     1.000000
# brand_consideration       0.600000      -0.40000       0.119523     0.600000
# brand_purchase           -0.200000      -0.80000       0.597614     0.600000
# brand_preference         -0.200000      -0.80000       0.597614     0.600000
#
#                      brand_consideration  brand_purchase  brand_preference
# perc_negative                   0.600000       -0.200000         -0.200000
# perc_neutral                   -0.400000       -0.800000         -0.800000
# perc_positive                   0.119523        0.597614          0.597614
# brand_aware                     0.600000        0.600000          0.600000
# brand_consideration             1.000000        0.200000          0.200000
# brand_purchase                  0.200000        1.000000          1.000000
# brand_preference                0.200000        1.000000          1.000000

# %%
sns.heatmap(data=cross_correlations_twitter, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(data=cross_correlations_survey_sub1, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(data=cross_correlations_survey_tot1, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Pearson Correlation

# %%
# Twitter
cross_correlations_twitter_pearson = twitter_ranked.corr(method="pearson")
cross_correlations_twitter_pearson
# Out:
#                   perc_negative  perc_neutral  perc_positive  share_of_voice  \
# perc_negative               1.0          -0.7            0.4             0.7
# perc_neutral               -0.7           1.0           -0.9            -0.2
# perc_positive               0.4          -0.9            1.0             0.1
# share_of_voice              0.7          -0.2            0.1             1.0
# retweets_mean               0.0          -0.3            0.6             0.3
# replies_mean                0.2          -0.3            0.4             0.3
# likes_mean                  0.1          -0.4            0.7             0.4
# quote_count_mean            0.1          -0.1            0.3             0.5
#
#                   retweets_mean  replies_mean  likes_mean  quote_count_mean
# perc_negative               0.0           0.2         0.1               0.1
# perc_neutral               -0.3          -0.3        -0.4              -0.1
# perc_positive               0.6           0.4         0.7               0.3
# share_of_voice              0.3           0.3         0.4               0.5
# retweets_mean               1.0           0.8         0.9               0.9
# replies_mean                0.8           1.0         0.5               0.9
# likes_mean                  0.9           0.5         1.0               0.7
# quote_count_mean            0.9           0.9         0.7               1.0

# %%
# Survey Total

cross_correlations_survey_tot2 = survey_tot_ranked.corr(method="pearson")
cross_correlations_survey_tot2
# Out:
#                      perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative             1.000000      0.100000      -0.447214      0.30000
# perc_neutral              0.100000      1.000000      -0.894427     -0.90000
# perc_positive            -0.447214     -0.894427       1.000000      0.67082
# brand_aware               0.300000     -0.900000       0.670820      1.00000
# brand_consideration       0.700000     -0.400000       0.223607      0.70000
# brand_purchase           -0.300000     -0.900000       0.782624      0.70000
# brand_preference         -0.300000     -0.900000       0.782624      0.70000
#
#                      brand_consideration  brand_purchase  brand_preference
# perc_negative                   0.700000       -0.300000         -0.300000
# perc_neutral                   -0.400000       -0.900000         -0.900000
# perc_positive                   0.223607        0.782624          0.782624
# brand_aware                     0.700000        0.700000          0.700000
# brand_consideration             1.000000        0.000000          0.000000
# brand_purchase                  0.000000        1.000000          1.000000
# brand_preference                0.000000        1.000000          1.000000

# %%
# Survey Sub sample

cross_correlations_survey_sub2 = survey_sub_ranked.corr(method = "pearson")
cross_correlations_survey_sub2
# Out:
#                      perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative             1.000000      0.461690      -0.718185    -0.564288
# perc_neutral              0.461690      1.000000      -0.900000    -0.700000
# perc_positive            -0.718185     -0.900000       1.000000     0.900000
# brand_aware              -0.564288     -0.700000       0.900000     1.000000
# brand_consideration      -0.872082     -0.800000       0.900000     0.700000
# brand_purchase           -0.815789     -0.872082       0.974679     0.820783
# brand_preference         -0.763158     -0.410391       0.564288     0.461690
#
#                      brand_consideration  brand_purchase  brand_preference
# perc_negative                  -0.872082       -0.815789         -0.763158
# perc_neutral                   -0.800000       -0.872082         -0.410391
# perc_positive                   0.900000        0.974679          0.564288
# brand_aware                     0.700000        0.820783          0.461690
# brand_consideration             1.000000        0.974679          0.820783
# brand_purchase                  0.974679        1.000000          0.710526
# brand_preference                0.820783        0.710526          1.000000

# %%
sns.heatmap(data=cross_correlations_twitter, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(data=cross_correlations_survey_tot2, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(data=cross_correlations_survey_sub2, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Please, repeat the same steps for the other data sets.

# %% [markdown]
# # Across-data correlations (Kendall)
#
# We also want to see correlations between KPIs of different data sets. So, let's combine two data sets with ranked data.

# %% [markdown]
# ## Correlation between Twitter & Survey Subsample (Twitter Savvy)

# %%
across_correlations1 = pd.DataFrame(index=twitter_ranked.columns, columns=survey_sub_ranked.columns, dtype="float")


# across_correlations1 : twitter_ranked & subsample_ranked 


for var_twitter in twitter_ranked:
    for var_survey in survey_sub_ranked:
        correlation = twitter_ranked[var_twitter].corr(survey_sub_ranked[var_survey], method="kendall")
        across_correlations1.loc[var_twitter, var_survey] = correlation

# %%
across_correlations1
# Out:
#                   perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative         -0.316228           0.0            0.2          0.0
# perc_neutral           0.316228           0.0           -0.2          0.0
# perc_positive         -0.316228           0.0            0.2          0.0
# share_of_voice        -0.737865          -0.4            0.6          0.4
# retweets_mean         -0.527046          -0.4            0.2          0.0
# replies_mean          -0.527046           0.0            0.2          0.0
# likes_mean            -0.316228          -0.6            0.4          0.2
# quote_count_mean      -0.737865          -0.2            0.4          0.2
#
#                   brand_consideration  brand_purchase  brand_preference
# perc_negative                    -0.4             0.4               0.4
# perc_neutral                      0.4            -0.4              -0.4
# perc_positive                    -0.4             0.4               0.4
# share_of_voice                    0.0             0.8               0.8
# retweets_mean                    -0.4             0.4               0.4
# replies_mean                     -0.4             0.4               0.4
# likes_mean                       -0.2             0.6               0.6
# quote_count_mean                 -0.2             0.6               0.6

# %%
# across_correlations1 : twitter_ranked & subsample_ranked

sns.heatmap(across_correlations1,cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Correlation between Twitter & Survey Total

# %%
across_correlations2 = pd.DataFrame(index=twitter_ranked.columns, columns=survey_tot_ranked.columns, dtype="float")


# across_correlations2 : twitter_ranked & survey_total_ranked 

for var_twitter in twitter_ranked:
    for var_survey in survey_tot_ranked:
        correlation = twitter_ranked[var_twitter].corr(survey_tot_ranked[var_survey], method="kendall")
        across_correlations2.loc[var_twitter, var_survey] = correlation
        
across_correlations2
# Out:
#                   perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative               0.0          -0.2      -0.119523          0.0
# perc_neutral                0.4          -0.2       0.119523          0.4
# perc_positive              -0.6           0.0       0.119523         -0.2
# share_of_voice              0.0          -0.6       0.358569          0.4
# retweets_mean              -0.8          -0.2       0.597614          0.0
# replies_mean               -0.8          -0.2       0.358569          0.0
# likes_mean                 -0.6          -0.4       0.597614          0.2
# quote_count_mean           -0.6          -0.4       0.597614          0.2
#
#                   brand_consideration  brand_purchase  brand_preference
# perc_negative                    -0.4             0.4               0.4
# perc_neutral                      0.8             0.0               0.0
# perc_positive                    -0.6             0.2               0.2
# share_of_voice                    0.0             0.8               0.8
# retweets_mean                    -0.4             0.4               0.4
# replies_mean                     -0.4             0.4               0.4
# likes_mean                       -0.2             0.6               0.6
# quote_count_mean                 -0.2             0.6               0.6

# %%
sns.heatmap(across_correlations2, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Correlation between Survey Total & Survey Subsample (Twitter Savvy)

# %%
across_correlations3 = pd.DataFrame(index=survey_sub_ranked.columns, columns=survey_tot_ranked.columns, dtype="float")


# across_correlations3 : survey_subsample_ranked & survey_total_ranked 


for var_sub in survey_sub_ranked:
    for var_tot in survey_tot_ranked:
        correlation = survey_sub_ranked[var_sub].corr(survey_tot_ranked[var_tot], method="kendall")
        across_correlations3.loc[var_sub, var_tot] = correlation
        
across_correlations3
# Out:
#                      perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative             0.316228      0.527046      -0.503953    -0.316228
# perc_neutral              0.200000      0.800000      -0.836660    -0.600000
# perc_positive             0.000000     -1.000000       0.836660     0.800000
# brand_aware               0.200000     -0.800000       0.597614     1.000000
# brand_consideration      -0.200000     -0.800000       0.597614     0.600000
# brand_purchase           -0.105409     -0.948683       0.755929     0.737865
# brand_preference          0.105409     -0.527046       0.251976     0.316228
#
#                      brand_consideration  brand_purchase  brand_preference
# perc_negative                   0.105409       -0.737865         -0.737865
# perc_neutral                   -0.200000       -0.600000         -0.600000
# perc_positive                   0.400000        0.800000          0.800000
# brand_aware                     0.600000        0.600000          0.600000
# brand_consideration             0.200000        1.000000          1.000000
# brand_purchase                  0.316228        0.948683          0.948683
# brand_preference               -0.105409        0.737865          0.737865

# %%
sns.heatmap(across_correlations3, cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Across-data correlations (Pearson)
#
# We also want to see correlations between KPIs of different data sets. So, let's combine two data sets with ranked data.

# %% [markdown]
# ## Correlation between Twitter & Survey Subsample (Twitter Savvy)

# %%
across_correlations1b = pd.DataFrame(index=twitter_ranked.columns, columns=survey_sub_ranked.columns, dtype="float")


# across_correlations1 : twitter_ranked & subsample_ranked 


for var_twitter in twitter_ranked:
    for var_survey in survey_sub_ranked:
        correlation = twitter_ranked[var_twitter].corr(survey_sub_ranked[var_survey], method="pearson")
        across_correlations1b.loc[var_twitter, var_survey] = correlation

# %%
across_correlations1b
# Out:
#                   perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative         -0.461690           0.1            0.0         -0.1
# perc_neutral           0.051299          -0.1            0.3          0.6
# perc_positive         -0.051299          -0.2           -0.1         -0.5
# share_of_voice        -0.872082          -0.5            0.7          0.6
# retweets_mean         -0.564288          -0.6            0.5          0.1
# replies_mean          -0.666886          -0.1            0.2         -0.1
# likes_mean            -0.461690          -0.8            0.6          0.2
# quote_count_mean      -0.820783          -0.5            0.6          0.3
#
#                   brand_consideration  brand_purchase  brand_preference
# perc_negative                     0.4        0.205196          0.820783
# perc_neutral                     -0.1        0.102598         -0.359092
# perc_positive                     0.2        0.051299          0.205196
# share_of_voice                    0.9        0.820783          0.974679
# retweets_mean                     0.6        0.564288          0.205196
# replies_mean                      0.4        0.307794          0.205196
# likes_mean                        0.7        0.666886          0.359092
# quote_count_mean                  0.7        0.666886          0.359092

# %%
# across_correlations1 : twitter_ranked & subsample_ranked

sns.heatmap(across_correlations1b,cmap="coolwarm", annot=True, 
            fmt='.2', vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Correlation between Twitter & Survey Total

# %%
across_correlations2b = pd.DataFrame(index=twitter_ranked.columns, columns=survey_tot_ranked.columns, dtype="float")


# across_correlations2 : twitter_ranked & survey_total_ranked 

for var_twitter in twitter_ranked:
    for var_survey in survey_tot_ranked:
        correlation = twitter_ranked[var_twitter].corr(survey_tot_ranked[var_survey], method="pearson")
        across_correlations2b.loc[var_twitter, var_survey] = correlation
        
across_correlations2b
# Out:
#                   perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative              -0.1           0.0      -0.223607         -0.1
# perc_neutral                0.5          -0.3       0.223607          0.6
# perc_positive              -0.7           0.1       0.111803         -0.5
# share_of_voice             -0.1          -0.7       0.447214          0.6
# retweets_mean              -0.9          -0.5       0.782624          0.1
# replies_mean               -0.9          -0.2       0.447214         -0.1
# likes_mean                 -0.7          -0.6       0.782624          0.2
# quote_count_mean           -0.8          -0.6       0.782624          0.3
#
#                   brand_consideration  brand_purchase  brand_preference
# perc_negative                    -0.6             0.4               0.4
# perc_neutral                      0.9            -0.1              -0.1
# perc_positive                    -0.8             0.2               0.2
# share_of_voice                   -0.1             0.9               0.9
# retweets_mean                    -0.4             0.6               0.6
# replies_mean                     -0.6             0.4               0.4
# likes_mean                       -0.3             0.7               0.7
# quote_count_mean                 -0.3             0.7               0.7

# %%
sns.heatmap(across_correlations2b, cmap="coolwarm", annot=True, 
            fmt='.2')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Correlation between Survey Total & Survey Subsample (Twitter Savvy)

# %%
across_correlations3b = pd.DataFrame(index=survey_sub_ranked.columns, columns=survey_tot_ranked.columns, dtype="float")


# across_correlations3 : survey_subsample_ranked & survey_total_ranked 


for var_sub in survey_sub_ranked:
    for var_tot in survey_tot_ranked:
        correlation = survey_sub_ranked[var_sub].corr(survey_tot_ranked[var_tot], method="pearson")
        across_correlations3b.loc[var_sub, var_tot] = correlation
        
across_correlations3b
# Out:
#                      perc_negative  perc_neutral  perc_positive  brand_aware  \
# perc_negative             0.410391      0.718185      -0.630893    -0.564288
# perc_neutral              0.200000      0.900000      -0.894427    -0.700000
# perc_positive            -0.100000     -1.000000       0.894427     0.900000
# brand_aware               0.300000     -0.900000       0.670820     1.000000
# brand_consideration       0.700000     -0.400000       0.223607     0.700000
# brand_purchase           -0.300000     -0.900000       0.782624     0.700000
# brand_preference         -0.300000     -0.900000       0.782624     0.700000
#
#                      brand_consideration  brand_purchase  brand_preference
# perc_negative                   0.153897       -0.872082         -0.872082
# perc_neutral                   -0.300000       -0.800000         -0.800000
# perc_positive                   0.400000        0.900000          0.900000
# brand_aware                     0.700000        0.700000          0.700000
# brand_consideration             1.000000        0.000000          0.000000
# brand_purchase                  0.000000        1.000000          1.000000
# brand_preference                0.000000        1.000000          1.000000

# %%
sns.heatmap(across_correlations3b, cmap="coolwarm", annot=True, 
            fmt='.2')
# Out:
# <AxesSubplot: >
