# %% [markdown]
# # An overview on KPIs
#
# This notebook provides an overview on the KPIs of all data sets and how they relate to each other.

# %%
import pandas as pd
import seaborn as sns

# %%
brands = ["Adidas", "Converse", "New Balance", "Nike","Reebok"]
sentiments = ["negative", "neutral", "positive"]

# %% [markdown]
# ## The data sets
#
# The data sets retrieved from each source should look similar to the stubs presented below.

# %% [markdown]
# Share of voice data source: [Link](https://github.com/HuanSunGo/Quantilope_Core/blob/main/src/tweet_analysis/twitter_frances/share_of_voice_franyang_nov10.ipynb) <br>
# Activities per tweet data source: [Link](https://github.com/HuanSunGo/Quantilope_Core/blob/main/src/tweet_analysis/twitter_frances/activities_per_tweet_franyang_nov10.ipynb)

# %%
# Add also the other KPIs for activities per tweet and share of voice as columns to the data set.
twitter_stub = pd.DataFrame(index=brands, columns=[f"{brand}_perc_{sentiment}" for brand in brands for sentiment in sentiments])

"""fill in the data from the previous calculations"""

# please fill in the sentiment percent below 
twitter_stub["Adidas_perc_negative"] = [0.6, 0.4, 0.3, 0.7, 0.2 ]
# twitter_stub["Adidas_perc_neutral"] = []
# ... 

# share of voice
twitter_stub['share_of_voice'] = [0.192406, 0.076869, 0.055327, 0.654862, 0.020535]

# activities per tweet 
twitter_stub['retweets_mean'] = [0.711236, 0.462702, 0.826331, 0.563720, 0.320755]
twitter_stub['replies_mean'] = [0.802255, 0.684476, 0.705882, 0.644066, 0.483019]
twitter_stub['likes_mean'] = [6.503826, 6.407258, 7.292717, 6.964975, 5.664151]
twitter_stub['quote_count_mean'] = [0.161498, 0.100806, 0.149860, 0.114898, 0.064151]

twitter_stub
# Out:
#              Adidas_perc_negative Adidas_perc_neutral Adidas_perc_positive  \
# Adidas                        0.6                 NaN                  NaN
# Converse                      0.4                 NaN                  NaN
# New Balance                   0.3                 NaN                  NaN
# Nike                          0.7                 NaN                  NaN
# Reebok                        0.2                 NaN                  NaN
#
#             Converse_perc_negative Converse_perc_neutral  \
# Adidas                         NaN                   NaN
# Converse                       NaN                   NaN
# New Balance                    NaN                   NaN
# Nike                           NaN                   NaN
# Reebok                         NaN                   NaN
#
#             Converse_perc_positive New Balance_perc_negative  \
# Adidas                         NaN                       NaN
# Converse                       NaN                       NaN
# New Balance                    NaN                       NaN
# Nike                           NaN                       NaN
# Reebok                         NaN                       NaN
#
#             New Balance_perc_neutral New Balance_perc_positive  \
# Adidas                           NaN                       NaN
# Converse                         NaN                       NaN
# New Balance                      NaN                       NaN
# Nike                             NaN                       NaN
# Reebok                           NaN                       NaN
#
#             Nike_perc_negative Nike_perc_neutral Nike_perc_positive  \
# Adidas                     NaN               NaN                NaN
# Converse                   NaN               NaN                NaN
# New Balance                NaN               NaN                NaN
# Nike                       NaN               NaN                NaN
# Reebok                     NaN               NaN                NaN
#
#             Reebok_perc_negative Reebok_perc_neutral Reebok_perc_positive  \
# Adidas                       NaN                 NaN                  NaN
# Converse                     NaN                 NaN                  NaN
# New Balance                  NaN                 NaN                  NaN
# Nike                         NaN                 NaN                  NaN
# Reebok                       NaN                 NaN                  NaN
#
#              share_of_voice  retweets_mean  replies_mean  likes_mean  \
# Adidas             0.192406       0.711236      0.802255    6.503826
# Converse           0.076869       0.462702      0.684476    6.407258
# New Balance        0.055327       0.826331      0.705882    7.292717
# Nike               0.654862       0.563720      0.644066    6.964975
# Reebok             0.020535       0.320755      0.483019    5.664151
#
#              quote_count_mean
# Adidas               0.161498
# Converse             0.100806
# New Balance          0.149860
# Nike                 0.114898
# Reebok               0.064151

# %% [markdown]
# ### Survey Table:
#
# Hey Shauna, I think Quantilope want to have different sentiment scores for all the samples, and put the corresponding results in the `survey_stub` table, and also run the sentiment model over the Twitter subsample, and fill in the `survey_twitter_savy_stub` table. If you have already done this part, please ignore it.

# %%
# Add also the other KPIs for image ratings and funnel metrics as columns to the data set.
survey_stub = pd.DataFrame(index=brands, columns=[f"{brand}_perc_{sentiment}" for brand in brands for sentiment in sentiments])

'''
Hi Shauna, I think you have already calculated these numbers, just plug them in will do. 
This part is for the total data set. 
'''
survey_stub["Adidas_perc_positive"] = [0.2, 0.6, 0.3, 0.15, 0.5] # replace this 
survey_stub
# Out:
#             Adidas_perc_negative Adidas_perc_neutral  Adidas_perc_positive  \
# Adidas                       NaN                 NaN                  0.20
# Converse                     NaN                 NaN                  0.60
# Nike                         NaN                 NaN                  0.30
# New Balance                  NaN                 NaN                  0.15
# Reebok                       NaN                 NaN                  0.50
#
#             Converse_perc_negative Converse_perc_neutral  \
# Adidas                         NaN                   NaN
# Converse                       NaN                   NaN
# Nike                           NaN                   NaN
# New Balance                    NaN                   NaN
# Reebok                         NaN                   NaN
#
#             Converse_perc_positive Nike_perc_negative Nike_perc_neutral  \
# Adidas                         NaN                NaN               NaN
# Converse                       NaN                NaN               NaN
# Nike                           NaN                NaN               NaN
# New Balance                    NaN                NaN               NaN
# Reebok                         NaN                NaN               NaN
#
#             Nike_perc_positive New Balance_perc_negative  \
# Adidas                     NaN                       NaN
# Converse                   NaN                       NaN
# Nike                       NaN                       NaN
# New Balance                NaN                       NaN
# Reebok                     NaN                       NaN
#
#             New Balance_perc_neutral New Balance_perc_positive  \
# Adidas                           NaN                       NaN
# Converse                         NaN                       NaN
# Nike                             NaN                       NaN
# New Balance                      NaN                       NaN
# Reebok                           NaN                       NaN
#
#             Reebok_perc_negative Reebok_perc_neutral Reebok_perc_positive
# Adidas                       NaN                 NaN                  NaN
# Converse                     NaN                 NaN                  NaN
# Nike                         NaN                 NaN                  NaN
# New Balance                  NaN                 NaN                  NaN
# Reebok                       NaN                 NaN                  NaN

# %%
# Add also the other KPIs for image ratings and funnel metrics as columns to the data set.
survey_twitter_savy_stub = pd.DataFrame(index=brands, columns=[f"{brand}_perc_{sentiment}" for brand in brands for sentiment in sentiments])
'''
This part is for the twitter subsample.
'''
survey_twitter_savy_stub
# Out:
#             Adidas_perc_negative Adidas_perc_neutral Adidas_perc_positive  \
# Adidas                       NaN                 NaN                  NaN
# Converse                     NaN                 NaN                  NaN
# Nike                         NaN                 NaN                  NaN
# New Balance                  NaN                 NaN                  NaN
# Reebok                       NaN                 NaN                  NaN
#
#             Converse_perc_negative Converse_perc_neutral  \
# Adidas                         NaN                   NaN
# Converse                       NaN                   NaN
# Nike                           NaN                   NaN
# New Balance                    NaN                   NaN
# Reebok                         NaN                   NaN
#
#             Converse_perc_positive Nike_perc_negative Nike_perc_neutral  \
# Adidas                         NaN                NaN               NaN
# Converse                       NaN                NaN               NaN
# Nike                           NaN                NaN               NaN
# New Balance                    NaN                NaN               NaN
# Reebok                         NaN                NaN               NaN
#
#             Nike_perc_positive New Balance_perc_negative  \
# Adidas                     NaN                       NaN
# Converse                   NaN                       NaN
# Nike                       NaN                       NaN
# New Balance                NaN                       NaN
# Reebok                     NaN                       NaN
#
#             New Balance_perc_neutral New Balance_perc_positive  \
# Adidas                           NaN                       NaN
# Converse                         NaN                       NaN
# Nike                             NaN                       NaN
# New Balance                      NaN                       NaN
# Reebok                           NaN                       NaN
#
#             Reebok_perc_negative Reebok_perc_neutral Reebok_perc_positive
# Adidas                       NaN                 NaN                  NaN
# Converse                     NaN                 NaN                  NaN
# Nike                         NaN                 NaN                  NaN
# New Balance                  NaN                 NaN                  NaN
# Reebok                       NaN                 NaN                  NaN

# %% [markdown]
# ## Within-data correlation
#
# Here, we want to see how KPIs within a data set are correlated with each other. For that, we first rank the data. Let us take the twitter data as an example.

# %%
twitter_stub
# Out:
#              Adidas_perc_negative Adidas_perc_neutral Adidas_perc_positive  \
# Adidas                        0.6                 NaN                  NaN
# Converse                      0.4                 NaN                  NaN
# New Balance                   0.3                 NaN                  NaN
# Nike                          0.7                 NaN                  NaN
# Reebok                        0.2                 NaN                  NaN
#
#             Converse_perc_negative Converse_perc_neutral  \
# Adidas                         NaN                   NaN
# Converse                       NaN                   NaN
# New Balance                    NaN                   NaN
# Nike                           NaN                   NaN
# Reebok                         NaN                   NaN
#
#             Converse_perc_positive New Balance_perc_negative  \
# Adidas                         NaN                       NaN
# Converse                       NaN                       NaN
# New Balance                    NaN                       NaN
# Nike                           NaN                       NaN
# Reebok                         NaN                       NaN
#
#             New Balance_perc_neutral New Balance_perc_positive  \
# Adidas                           NaN                       NaN
# Converse                         NaN                       NaN
# New Balance                      NaN                       NaN
# Nike                             NaN                       NaN
# Reebok                           NaN                       NaN
#
#             Nike_perc_negative Nike_perc_neutral Nike_perc_positive  \
# Adidas                     NaN               NaN                NaN
# Converse                   NaN               NaN                NaN
# New Balance                NaN               NaN                NaN
# Nike                       NaN               NaN                NaN
# Reebok                     NaN               NaN                NaN
#
#             Reebok_perc_negative Reebok_perc_neutral Reebok_perc_positive  \
# Adidas                       NaN                 NaN                  NaN
# Converse                     NaN                 NaN                  NaN
# New Balance                  NaN                 NaN                  NaN
# Nike                         NaN                 NaN                  NaN
# Reebok                       NaN                 NaN                  NaN
#
#              share_of_voice  retweets_mean  replies_mean  likes_mean  \
# Adidas             0.192406       0.711236      0.802255    6.503826
# Converse           0.076869       0.462702      0.684476    6.407258
# New Balance        0.055327       0.826331      0.705882    7.292717
# Nike               0.654862       0.563720      0.644066    6.964975
# Reebok             0.020535       0.320755      0.483019    5.664151
#
#              quote_count_mean
# Adidas               0.161498
# Converse             0.100806
# New Balance          0.149860
# Nike                 0.114898
# Reebok               0.064151

# %%
twitter_ranked = twitter_stub.rank(axis="index", ascending=False)
twitter_ranked
# Out:
#              Adidas_perc_negative  Adidas_perc_neutral  Adidas_perc_positive  \
# Adidas                        2.0                  NaN                   NaN
# Converse                      3.0                  NaN                   NaN
# New Balance                   4.0                  NaN                   NaN
# Nike                          1.0                  NaN                   NaN
# Reebok                        5.0                  NaN                   NaN
#
#              Converse_perc_negative  Converse_perc_neutral  \
# Adidas                          NaN                    NaN
# Converse                        NaN                    NaN
# New Balance                     NaN                    NaN
# Nike                            NaN                    NaN
# Reebok                          NaN                    NaN
#
#              Converse_perc_positive  New Balance_perc_negative  \
# Adidas                          NaN                        NaN
# Converse                        NaN                        NaN
# New Balance                     NaN                        NaN
# Nike                            NaN                        NaN
# Reebok                          NaN                        NaN
#
#              New Balance_perc_neutral  New Balance_perc_positive  \
# Adidas                            NaN                        NaN
# Converse                          NaN                        NaN
# New Balance                       NaN                        NaN
# Nike                              NaN                        NaN
# Reebok                            NaN                        NaN
#
#              Nike_perc_negative  Nike_perc_neutral  Nike_perc_positive  \
# Adidas                      NaN                NaN                 NaN
# Converse                    NaN                NaN                 NaN
# New Balance                 NaN                NaN                 NaN
# Nike                        NaN                NaN                 NaN
# Reebok                      NaN                NaN                 NaN
#
#              Reebok_perc_negative  Reebok_perc_neutral  Reebok_perc_positive  \
# Adidas                        NaN                  NaN                   NaN
# Converse                      NaN                  NaN                   NaN
# New Balance                   NaN                  NaN                   NaN
# Nike                          NaN                  NaN                   NaN
# Reebok                        NaN                  NaN                   NaN
#
#              share_of_voice  retweets_mean  replies_mean  likes_mean  \
# Adidas                  2.0            2.0           1.0         3.0
# Converse                3.0            4.0           3.0         4.0
# New Balance             4.0            1.0           2.0         1.0
# Nike                    1.0            3.0           4.0         2.0
# Reebok                  5.0            5.0           5.0         5.0
#
#              quote_count_mean
# Adidas                    1.0
# Converse                  4.0
# New Balance               2.0
# Nike                      3.0
# Reebok                    5.0

# %% [markdown]
# Now, that all the KPIs are ranked, let's calculate Kendall's tau for each combination of KPIs.

# %%
cross_correlations = twitter_ranked.corr(method="kendall")

# %%
cross_correlations
# Out:
#                            Adidas_perc_negative  Adidas_perc_neutral  \
# Adidas_perc_negative                        1.0                  NaN
# Adidas_perc_neutral                         NaN                  NaN
# Adidas_perc_positive                        NaN                  NaN
# Converse_perc_negative                      NaN                  NaN
# Converse_perc_neutral                       NaN                  NaN
# Converse_perc_positive                      NaN                  NaN
# New Balance_perc_negative                   NaN                  NaN
# New Balance_perc_neutral                    NaN                  NaN
# New Balance_perc_positive                   NaN                  NaN
# Nike_perc_negative                          NaN                  NaN
# Nike_perc_neutral                           NaN                  NaN
# Nike_perc_positive                          NaN                  NaN
# Reebok_perc_negative                        NaN                  NaN
# Reebok_perc_neutral                         NaN                  NaN
# Reebok_perc_positive                        NaN                  NaN
# share_of_voice                              1.0                  NaN
# retweets_mean                               0.2                  NaN
# replies_mean                                0.2                  NaN
# likes_mean                                  0.4                  NaN
# quote_count_mean                            0.4                  NaN
#
#                            Adidas_perc_positive  Converse_perc_negative  \
# Adidas_perc_negative                        NaN                     NaN
# Adidas_perc_neutral                         NaN                     NaN
# Adidas_perc_positive                        NaN                     NaN
# Converse_perc_negative                      NaN                     NaN
# Converse_perc_neutral                       NaN                     NaN
# Converse_perc_positive                      NaN                     NaN
# New Balance_perc_negative                   NaN                     NaN
# New Balance_perc_neutral                    NaN                     NaN
# New Balance_perc_positive                   NaN                     NaN
# Nike_perc_negative                          NaN                     NaN
# Nike_perc_neutral                           NaN                     NaN
# Nike_perc_positive                          NaN                     NaN
# Reebok_perc_negative                        NaN                     NaN
# Reebok_perc_neutral                         NaN                     NaN
# Reebok_perc_positive                        NaN                     NaN
# share_of_voice                              NaN                     NaN
# retweets_mean                               NaN                     NaN
# replies_mean                                NaN                     NaN
# likes_mean                                  NaN                     NaN
# quote_count_mean                            NaN                     NaN
#
#                            Converse_perc_neutral  Converse_perc_positive  \
# Adidas_perc_negative                         NaN                     NaN
# Adidas_perc_neutral                          NaN                     NaN
# Adidas_perc_positive                         NaN                     NaN
# Converse_perc_negative                       NaN                     NaN
# Converse_perc_neutral                        NaN                     NaN
# Converse_perc_positive                       NaN                     NaN
# New Balance_perc_negative                    NaN                     NaN
# New Balance_perc_neutral                     NaN                     NaN
# New Balance_perc_positive                    NaN                     NaN
# Nike_perc_negative                           NaN                     NaN
# Nike_perc_neutral                            NaN                     NaN
# Nike_perc_positive                           NaN                     NaN
# Reebok_perc_negative                         NaN                     NaN
# Reebok_perc_neutral                          NaN                     NaN
# Reebok_perc_positive                         NaN                     NaN
# share_of_voice                               NaN                     NaN
# retweets_mean                                NaN                     NaN
# replies_mean                                 NaN                     NaN
# likes_mean                                   NaN                     NaN
# quote_count_mean                             NaN                     NaN
#
#                            New Balance_perc_negative  \
# Adidas_perc_negative                             NaN
# Adidas_perc_neutral                              NaN
# Adidas_perc_positive                             NaN
# Converse_perc_negative                           NaN
# Converse_perc_neutral                            NaN
# Converse_perc_positive                           NaN
# New Balance_perc_negative                        NaN
# New Balance_perc_neutral                         NaN
# New Balance_perc_positive                        NaN
# Nike_perc_negative                               NaN
# Nike_perc_neutral                                NaN
# Nike_perc_positive                               NaN
# Reebok_perc_negative                             NaN
# Reebok_perc_neutral                              NaN
# Reebok_perc_positive                             NaN
# share_of_voice                                   NaN
# retweets_mean                                    NaN
# replies_mean                                     NaN
# likes_mean                                       NaN
# quote_count_mean                                 NaN
#
#                            New Balance_perc_neutral  \
# Adidas_perc_negative                            NaN
# Adidas_perc_neutral                             NaN
# Adidas_perc_positive                            NaN
# Converse_perc_negative                          NaN
# Converse_perc_neutral                           NaN
# Converse_perc_positive                          NaN
# New Balance_perc_negative                       NaN
# New Balance_perc_neutral                        NaN
# New Balance_perc_positive                       NaN
# Nike_perc_negative                              NaN
# Nike_perc_neutral                               NaN
# Nike_perc_positive                              NaN
# Reebok_perc_negative                            NaN
# Reebok_perc_neutral                             NaN
# Reebok_perc_positive                            NaN
# share_of_voice                                  NaN
# retweets_mean                                   NaN
# replies_mean                                    NaN
# likes_mean                                      NaN
# quote_count_mean                                NaN
#
#                            New Balance_perc_positive  Nike_perc_negative  \
# Adidas_perc_negative                             NaN                 NaN
# Adidas_perc_neutral                              NaN                 NaN
# Adidas_perc_positive                             NaN                 NaN
# Converse_perc_negative                           NaN                 NaN
# Converse_perc_neutral                            NaN                 NaN
# Converse_perc_positive                           NaN                 NaN
# New Balance_perc_negative                        NaN                 NaN
# New Balance_perc_neutral                         NaN                 NaN
# New Balance_perc_positive                        NaN                 NaN
# Nike_perc_negative                               NaN                 NaN
# Nike_perc_neutral                                NaN                 NaN
# Nike_perc_positive                               NaN                 NaN
# Reebok_perc_negative                             NaN                 NaN
# Reebok_perc_neutral                              NaN                 NaN
# Reebok_perc_positive                             NaN                 NaN
# share_of_voice                                   NaN                 NaN
# retweets_mean                                    NaN                 NaN
# replies_mean                                     NaN                 NaN
# likes_mean                                       NaN                 NaN
# quote_count_mean                                 NaN                 NaN
#
#                            Nike_perc_neutral  Nike_perc_positive  \
# Adidas_perc_negative                     NaN                 NaN
# Adidas_perc_neutral                      NaN                 NaN
# Adidas_perc_positive                     NaN                 NaN
# Converse_perc_negative                   NaN                 NaN
# Converse_perc_neutral                    NaN                 NaN
# Converse_perc_positive                   NaN                 NaN
# New Balance_perc_negative                NaN                 NaN
# New Balance_perc_neutral                 NaN                 NaN
# New Balance_perc_positive                NaN                 NaN
# Nike_perc_negative                       NaN                 NaN
# Nike_perc_neutral                        NaN                 NaN
# Nike_perc_positive                       NaN                 NaN
# Reebok_perc_negative                     NaN                 NaN
# Reebok_perc_neutral                      NaN                 NaN
# Reebok_perc_positive                     NaN                 NaN
# share_of_voice                           NaN                 NaN
# retweets_mean                            NaN                 NaN
# replies_mean                             NaN                 NaN
# likes_mean                               NaN                 NaN
# quote_count_mean                         NaN                 NaN
#
#                            Reebok_perc_negative  Reebok_perc_neutral  \
# Adidas_perc_negative                        NaN                  NaN
# Adidas_perc_neutral                         NaN                  NaN
# Adidas_perc_positive                        NaN                  NaN
# Converse_perc_negative                      NaN                  NaN
# Converse_perc_neutral                       NaN                  NaN
# Converse_perc_positive                      NaN                  NaN
# New Balance_perc_negative                   NaN                  NaN
# New Balance_perc_neutral                    NaN                  NaN
# New Balance_perc_positive                   NaN                  NaN
# Nike_perc_negative                          NaN                  NaN
# Nike_perc_neutral                           NaN                  NaN
# Nike_perc_positive                          NaN                  NaN
# Reebok_perc_negative                        NaN                  NaN
# Reebok_perc_neutral                         NaN                  NaN
# Reebok_perc_positive                        NaN                  NaN
# share_of_voice                              NaN                  NaN
# retweets_mean                               NaN                  NaN
# replies_mean                                NaN                  NaN
# likes_mean                                  NaN                  NaN
# quote_count_mean                            NaN                  NaN
#
#                            Reebok_perc_positive  share_of_voice  \
# Adidas_perc_negative                        NaN             1.0
# Adidas_perc_neutral                         NaN             NaN
# Adidas_perc_positive                        NaN             NaN
# Converse_perc_negative                      NaN             NaN
# Converse_perc_neutral                       NaN             NaN
# Converse_perc_positive                      NaN             NaN
# New Balance_perc_negative                   NaN             NaN
# New Balance_perc_neutral                    NaN             NaN
# New Balance_perc_positive                   NaN             NaN
# Nike_perc_negative                          NaN             NaN
# Nike_perc_neutral                           NaN             NaN
# Nike_perc_positive                          NaN             NaN
# Reebok_perc_negative                        NaN             NaN
# Reebok_perc_neutral                         NaN             NaN
# Reebok_perc_positive                        NaN             NaN
# share_of_voice                              NaN             1.0
# retweets_mean                               NaN             0.2
# replies_mean                                NaN             0.2
# likes_mean                                  NaN             0.4
# quote_count_mean                            NaN             0.4
#
#                            retweets_mean  replies_mean  likes_mean  \
# Adidas_perc_negative                 0.2           0.2         0.4
# Adidas_perc_neutral                  NaN           NaN         NaN
# Adidas_perc_positive                 NaN           NaN         NaN
# Converse_perc_negative               NaN           NaN         NaN
# Converse_perc_neutral                NaN           NaN         NaN
# Converse_perc_positive               NaN           NaN         NaN
# New Balance_perc_negative            NaN           NaN         NaN
# New Balance_perc_neutral             NaN           NaN         NaN
# New Balance_perc_positive            NaN           NaN         NaN
# Nike_perc_negative                   NaN           NaN         NaN
# Nike_perc_neutral                    NaN           NaN         NaN
# Nike_perc_positive                   NaN           NaN         NaN
# Reebok_perc_negative                 NaN           NaN         NaN
# Reebok_perc_neutral                  NaN           NaN         NaN
# Reebok_perc_positive                 NaN           NaN         NaN
# share_of_voice                       0.2           0.2         0.4
# retweets_mean                        1.0           0.6         0.8
# replies_mean                         0.6           1.0         0.4
# likes_mean                           0.8           0.4         1.0
# quote_count_mean                     0.8           0.8         0.6
#
#                            quote_count_mean
# Adidas_perc_negative                    0.4
# Adidas_perc_neutral                     NaN
# Adidas_perc_positive                    NaN
# Converse_perc_negative                  NaN
# Converse_perc_neutral                   NaN
# Converse_perc_positive                  NaN
# New Balance_perc_negative               NaN
# New Balance_perc_neutral                NaN
# New Balance_perc_positive               NaN
# Nike_perc_negative                      NaN
# Nike_perc_neutral                       NaN
# Nike_perc_positive                      NaN
# Reebok_perc_negative                    NaN
# Reebok_perc_neutral                     NaN
# Reebok_perc_positive                    NaN
# share_of_voice                          0.4
# retweets_mean                           0.8
# replies_mean                            0.8
# likes_mean                              0.6
# quote_count_mean                        1.0

# %% [markdown]
# Now, let's visualize the correlations which is easier than skimming the numbers.

# %%
sns.heatmap(data=cross_correlations)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Please, repeat the same steps for the other data sets.

# %% [markdown]
# ## Across-data correlations
#
# We also want to see correlations between KPIs of different data sets. So, let's combine two data sets with ranked data.

# %%
survey_ranked = survey_stub.rank(axis="index", ascending=False)
survey_ranked
# Out:
#              Adidas_perc_negative  Adidas_perc_neutral  Adidas_perc_positive  \
# Adidas                        NaN                  NaN                   4.0
# Converse                      NaN                  NaN                   1.0
# Nike                          NaN                  NaN                   3.0
# New Balance                   NaN                  NaN                   5.0
# Reebok                        NaN                  NaN                   2.0
#
#              Converse_perc_negative  Converse_perc_neutral  \
# Adidas                          NaN                    NaN
# Converse                        NaN                    NaN
# Nike                            NaN                    NaN
# New Balance                     NaN                    NaN
# Reebok                          NaN                    NaN
#
#              Converse_perc_positive  Nike_perc_negative  Nike_perc_neutral  \
# Adidas                          NaN                 NaN                NaN
# Converse                        NaN                 NaN                NaN
# Nike                            NaN                 NaN                NaN
# New Balance                     NaN                 NaN                NaN
# Reebok                          NaN                 NaN                NaN
#
#              Nike_perc_positive  New Balance_perc_negative  \
# Adidas                      NaN                        NaN
# Converse                    NaN                        NaN
# Nike                        NaN                        NaN
# New Balance                 NaN                        NaN
# Reebok                      NaN                        NaN
#
#              New Balance_perc_neutral  New Balance_perc_positive  \
# Adidas                            NaN                        NaN
# Converse                          NaN                        NaN
# Nike                              NaN                        NaN
# New Balance                       NaN                        NaN
# Reebok                            NaN                        NaN
#
#              Reebok_perc_negative  Reebok_perc_neutral  Reebok_perc_positive
# Adidas                        NaN                  NaN                   NaN
# Converse                      NaN                  NaN                   NaN
# Nike                          NaN                  NaN                   NaN
# New Balance                   NaN                  NaN                   NaN
# Reebok                        NaN                  NaN                   NaN

# %%
across_correlations = pd.DataFrame(index=twitter_ranked.columns, columns=survey_ranked.columns, dtype="float")

for var_twitter in twitter_ranked:
    for var_survey in survey_ranked:
        correlation = twitter_ranked[var_twitter].corr(survey_ranked[var_survey], method="kendall")
        across_correlations.loc[var_twitter, var_survey] = correlation

# %%
across_correlations
# Out:
#                            Adidas_perc_negative  Adidas_perc_neutral  \
# Adidas_perc_negative                        NaN                  NaN
# Adidas_perc_neutral                         NaN                  NaN
# Adidas_perc_positive                        NaN                  NaN
# Converse_perc_negative                      NaN                  NaN
# Converse_perc_neutral                       NaN                  NaN
# Converse_perc_positive                      NaN                  NaN
# Nike_perc_negative                          NaN                  NaN
# Nike_perc_neutral                           NaN                  NaN
# Nike_perc_positive                          NaN                  NaN
# New Balance_perc_negative                   NaN                  NaN
# New Balance_perc_neutral                    NaN                  NaN
# New Balance_perc_positive                   NaN                  NaN
# Reebok_perc_negative                        NaN                  NaN
# Reebok_perc_neutral                         NaN                  NaN
# Reebok_perc_positive                        NaN                  NaN
#
#                            Adidas_perc_positive  Converse_perc_negative  \
# Adidas_perc_negative                       -0.6                     NaN
# Adidas_perc_neutral                         NaN                     NaN
# Adidas_perc_positive                        NaN                     NaN
# Converse_perc_negative                      NaN                     NaN
# Converse_perc_neutral                       NaN                     NaN
# Converse_perc_positive                      NaN                     NaN
# Nike_perc_negative                          NaN                     NaN
# Nike_perc_neutral                           NaN                     NaN
# Nike_perc_positive                          NaN                     NaN
# New Balance_perc_negative                   NaN                     NaN
# New Balance_perc_neutral                    NaN                     NaN
# New Balance_perc_positive                   NaN                     NaN
# Reebok_perc_negative                        NaN                     NaN
# Reebok_perc_neutral                         NaN                     NaN
# Reebok_perc_positive                        NaN                     NaN
#
#                            Converse_perc_neutral  Converse_perc_positive  \
# Adidas_perc_negative                         NaN                     NaN
# Adidas_perc_neutral                          NaN                     NaN
# Adidas_perc_positive                         NaN                     NaN
# Converse_perc_negative                       NaN                     NaN
# Converse_perc_neutral                        NaN                     NaN
# Converse_perc_positive                       NaN                     NaN
# Nike_perc_negative                           NaN                     NaN
# Nike_perc_neutral                            NaN                     NaN
# Nike_perc_positive                           NaN                     NaN
# New Balance_perc_negative                    NaN                     NaN
# New Balance_perc_neutral                     NaN                     NaN
# New Balance_perc_positive                    NaN                     NaN
# Reebok_perc_negative                         NaN                     NaN
# Reebok_perc_neutral                          NaN                     NaN
# Reebok_perc_positive                         NaN                     NaN
#
#                            Nike_perc_negative  Nike_perc_neutral  \
# Adidas_perc_negative                      NaN                NaN
# Adidas_perc_neutral                       NaN                NaN
# Adidas_perc_positive                      NaN                NaN
# Converse_perc_negative                    NaN                NaN
# Converse_perc_neutral                     NaN                NaN
# Converse_perc_positive                    NaN                NaN
# Nike_perc_negative                        NaN                NaN
# Nike_perc_neutral                         NaN                NaN
# Nike_perc_positive                        NaN                NaN
# New Balance_perc_negative                 NaN                NaN
# New Balance_perc_neutral                  NaN                NaN
# New Balance_perc_positive                 NaN                NaN
# Reebok_perc_negative                      NaN                NaN
# Reebok_perc_neutral                       NaN                NaN
# Reebok_perc_positive                      NaN                NaN
#
#                            Nike_perc_positive  New Balance_perc_negative  \
# Adidas_perc_negative                      NaN                        NaN
# Adidas_perc_neutral                       NaN                        NaN
# Adidas_perc_positive                      NaN                        NaN
# Converse_perc_negative                    NaN                        NaN
# Converse_perc_neutral                     NaN                        NaN
# Converse_perc_positive                    NaN                        NaN
# Nike_perc_negative                        NaN                        NaN
# Nike_perc_neutral                         NaN                        NaN
# Nike_perc_positive                        NaN                        NaN
# New Balance_perc_negative                 NaN                        NaN
# New Balance_perc_neutral                  NaN                        NaN
# New Balance_perc_positive                 NaN                        NaN
# Reebok_perc_negative                      NaN                        NaN
# Reebok_perc_neutral                       NaN                        NaN
# Reebok_perc_positive                      NaN                        NaN
#
#                            New Balance_perc_neutral  \
# Adidas_perc_negative                            NaN
# Adidas_perc_neutral                             NaN
# Adidas_perc_positive                            NaN
# Converse_perc_negative                          NaN
# Converse_perc_neutral                           NaN
# Converse_perc_positive                          NaN
# Nike_perc_negative                              NaN
# Nike_perc_neutral                               NaN
# Nike_perc_positive                              NaN
# New Balance_perc_negative                       NaN
# New Balance_perc_neutral                        NaN
# New Balance_perc_positive                       NaN
# Reebok_perc_negative                            NaN
# Reebok_perc_neutral                             NaN
# Reebok_perc_positive                            NaN
#
#                            New Balance_perc_positive  Reebok_perc_negative  \
# Adidas_perc_negative                             NaN                   NaN
# Adidas_perc_neutral                              NaN                   NaN
# Adidas_perc_positive                             NaN                   NaN
# Converse_perc_negative                           NaN                   NaN
# Converse_perc_neutral                            NaN                   NaN
# Converse_perc_positive                           NaN                   NaN
# Nike_perc_negative                               NaN                   NaN
# Nike_perc_neutral                                NaN                   NaN
# Nike_perc_positive                               NaN                   NaN
# New Balance_perc_negative                        NaN                   NaN
# New Balance_perc_neutral                         NaN                   NaN
# New Balance_perc_positive                        NaN                   NaN
# Reebok_perc_negative                             NaN                   NaN
# Reebok_perc_neutral                              NaN                   NaN
# Reebok_perc_positive                             NaN                   NaN
#
#                            Reebok_perc_neutral  Reebok_perc_positive
# Adidas_perc_negative                       NaN                   NaN
# Adidas_perc_neutral                        NaN                   NaN
# Adidas_perc_positive                       NaN                   NaN
# Converse_perc_negative                     NaN                   NaN
# Converse_perc_neutral                      NaN                   NaN
# Converse_perc_positive                     NaN                   NaN
# Nike_perc_negative                         NaN                   NaN
# Nike_perc_neutral                          NaN                   NaN
# Nike_perc_positive                         NaN                   NaN
# New Balance_perc_negative                  NaN                   NaN
# New Balance_perc_neutral                   NaN                   NaN
# New Balance_perc_positive                  NaN                   NaN
# Reebok_perc_negative                       NaN                   NaN
# Reebok_perc_neutral                        NaN                   NaN
# Reebok_perc_positive                       NaN                   NaN

# %%
sns.heatmap(across_correlations)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Repeat this for all the other combinations of data sets.
