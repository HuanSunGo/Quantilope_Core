# %%
import tweepy
import time
import pandas as pd

# %%
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAGLLhgEAAAAA1aGUpgPRg1fa8jo5sgy7dpshzNg%3D6RVr4MCm9qHTe3SzL8FhxJlqwzW5qdeR9MwWZ8wwEb4FNLM8vZ',wait_on_rate_limit=True)

# %%
# Sneakers
sneakers_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'sneakers -is:retweet lang:en place_country:US',
                                 user_fields = ['id', 'username', 'name', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['id','created_at', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    sneakers_tweets.append(response)
    
result = []
user_dict = {}

for response in sneakers_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'id': user.id,
                              'username': user.username, 
                              'name': user.name,
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_name': author_info['name'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'tweet_id': tweet.id,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df = pd.DataFrame(result)

df['type'] = 'Sneakers'
df
# Out:
#                 author_id        username  \
# 0     1493612427304488965         1KHABYS
# 1                29560488      CarrieMae_
# 2                22680919    MattHalfhill
# 3      997270922976481282    JEFF_SON_334
# 4               101915799     kwamemorgan
# ...                   ...             ...
# 2758            465886230         pshew09
# 2759  1348396865042132992      madzfortbz
# 2760  1553873902606004224  ShopTheDrop253
# 2761           1684503212      stylscourt
# 2762            160783887        illiotti
#
#                               author_name  author_followers  author_tweets  \
# 0                                 1KHABYS               133           2347
# 1                     Diary Entry #314509               345          12299
# 2                           Matt Halfhill             13051            583
# 3     🏁🏁🥋🏈Bishop Sycamore Starting CB🏈🥋🏁🏁               625           3917
# 4                            Kwame Morgan               848          25469
# ...

# %%
# Boots
boots_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'boots -is:retweet lang:en place_country:US',
                                 user_fields = ['id', 'username', 'name', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['id','created_at', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    boots_tweets.append(response)
    
result = []
user_dict = {}

for response in boots_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'id': user.id,
                              'username': user.username, 
                              'name': user.name,
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_name': author_info['name'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'tweet_id': tweet.id,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df2 = pd.DataFrame(result)

df2['type'] = 'Boots'
df2
# Out:
#                 author_id         username                    author_name  \
# 0               238781995  Mr_Nonautomatic                    $UGA~N~TANK
# 1      873591777047052288   VigilanteWayz_                Brodrick Watson
# 2     1519061530205171712       navy80to04                     navy80to04
# 3                37000068         chucko24                   Chuck Warner
# 4               525947526    ayheitscarter                         Carter
# ...                   ...              ...                            ...
# 6946             17635873  eleanoralenoraa                   bloody elle🩸
# 6947           2320525095   MannyTheHooper  El Hijo del KANEKI | WP | LNG
# 6948           4514169209      joyreeves23             Joy Reeves🗣🌈🏳️‍🌈🇺🇲
# 6949           1293734154       StevieJPTX          Cowboys Due Diligence
# 6950  1198993525964247042      BadBeatsLex                            Lex
#
#       author_followers  author_tweets  \
# 0                 1868          35638
# ...

# %%
# Loafers

loafers_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'loafers -is:retweet lang:en place_country:US',
                                 user_fields = ['id', 'username', 'name', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['id','created_at', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    loafers_tweets.append(response)
    
result = []
user_dict = {}

for response in loafers_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'id': user.id,
                              'username': user.username, 
                              'name': user.name,
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_name': author_info['name'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'tweet_id': tweet.id,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df3 = pd.DataFrame(result)

df3['type'] = 'Loafers'
df3
# Out:
#                author_id         username                    author_name  \
# 0              197907864      Nautinole24                         Baby J
# 1             3193779470      Protrending                    ProTrending
# 2              383627441     Lars_Griffin               Lawrence Griffin
# 3     737929982018768900          oddtank                           tank
# 4              208428580     CallMeMoprah  Moriah “Tall Energy” Stephens
# ..                   ...              ...                            ...
# 233           3044590740         babymp3_                     ♀trinity ♂
# 234           1119877860       resipsausa                       Res Ipsa
# 235   733432147214635008   sleepyboiMoosh              𝑺𝒍𝒆𝒆𝒑𝒚𝒃𝒐𝒊 𝑴𝒐𝒐𝒔𝒉🌩️
# 236            615790487       britsjoint                              !
# 237  1244838529571655687  DinahHouseFire1               Dinah House-Fire
#
#      author_followers  author_tweets  \
# 0                 155           4166
# ...

# %%
# Business shoes

bs_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'business shoes -is:retweet lang:en place_country:US',
                                 user_fields = ['id', 'username', 'name', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['id','created_at', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    bs_tweets.append(response)
    
result = []
user_dict = {}

for response in bs_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'id': user.id,
                              'username': user.username, 
                              'name': user.name,
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_name': author_info['name'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'tweet_id': tweet.id,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df4 = pd.DataFrame(result)

df4['type'] = 'Business Shoes'
df4
# Out:
#               author_id         username               author_name  \
# 0   1346251451950104577  MonicaWhitman17                  Leighann
# 1              49516492       BonniePuns                 boo-renna
# 2            2714308257   anissagardizy8            Anissa Gardizy
# 3            2714308257   anissagardizy8            Anissa Gardizy
# 4            2714308257   anissagardizy8            Anissa Gardizy
# ..                  ...              ...                       ...
# 70             15728819         npssandy                     Sandy
# 71           4044116063    LoveeeeeShay_            SuperSHAYdee ✨
# 72             36808473      kinjipscott               Kinji Scott
# 73             16099690    FrederickMelo  Frederick Melo, Reporter
# 74            355374842       MrNateDunn   Mr. Nate N. Dunn, M.Ed.
#
#     author_followers  author_tweets  \
# 0                 30           1898
# 1               4985          59202
# 2               3161           2617
# ...

# %%
# Slippers

slippers_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'slippers -is:retweet lang:en place_country:US',
                                 user_fields = ['id', 'username', 'name', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['id','created_at', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    slippers_tweets.append(response)
    
result = []
user_dict = {}

for response in slippers_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'id': user.id,
                              'username': user.username, 
                              'name': user.name,
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_name': author_info['name'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'tweet_id': tweet.id,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df5 = pd.DataFrame(result)

df5['type'] = 'Slippers'
df5
# Out:
#                author_id         username                 author_name  \
# 0              238842169           emhed_               emily hedrick
# 1    1484605226220982277  intern3tthottie                 Jizzel Rose
# 2             1454713914    DedeVotesBlue  VotingRightsNow☮️🙏🏾🙏🙏🏽🙏🏻🙏🏿
# 3               81259499         mzd1mple                         제미린
# 4     903094879412035584      Sarah_RN_WI             SarahRN 💙💛 🩺 🌈🩺
# ..                   ...              ...                         ...
# 635  1547059238924853248       sa61740585                         LiS
# 636  1549659659916947456     Jesse_110990                Jesse Helene
# 637             90895400   StanleyRoberts             Stanley Roberts
# 638  1462799619134533632         CuhCRYST                     Crystal
# 639   734900756784914432           beeljo                    Jon Best
#
#      author_followers  author_tweets  \
# 0                 586          45754
# 1                1432            844
# ...

# %%
# Sandals

sandals_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'sandals -is:retweet lang:en place_country:US',
                                 user_fields = ['id', 'username', 'name', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['id','created_at', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    sandals_tweets.append(response)
    
result = []
user_dict = {}

for response in sandals_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'id': user.id,
                              'username': user.username, 
                              'name': user.name,
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_name': author_info['name'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'tweet_id': tweet.id,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df6 = pd.DataFrame(result)

df6['type'] = 'Sandals'
df6
# Out:
#                 author_id         username  \
# 0              3342189372      ashzamorano
# 1                22098235   MelodyOrganics
# 2               259148967  andrewpelletier
# 3     1489348395017781252  dontbeweirdtome
# 4              3505560323  NiteniteMelissa
# ...                   ...              ...
# 1035            304179492        blewis823
# 1036  1001178515256107009   ashtagnofilter
# 1037  1539087986461114368     MouldofSteel
# 1038           1352673810    Kirbadactal23
# 1039            231979119    CaramelFrost_
#
#                                             author_name  author_followers  \
# 0                                                ashley               635
# 1                                      Melody Ann Jones               903
# 2                                            Fur Trader               372
# 3                                 F.U.C.K. House H.O.E.               127
# ...

# %%
df_concat = pd.concat([df, df2, df3, df4, df5, df6])

# %%
df_concat
# Out:
#                 author_id        username  \
# 0     1493612427304488965         1KHABYS
# 1                29560488      CarrieMae_
# 2                22680919    MattHalfhill
# 3      997270922976481282    JEFF_SON_334
# 4               101915799     kwamemorgan
# ...                   ...             ...
# 1035            304179492       blewis823
# 1036  1001178515256107009  ashtagnofilter
# 1037  1539087986461114368    MouldofSteel
# 1038           1352673810   Kirbadactal23
# 1039            231979119   CaramelFrost_
#
#                                             author_name  author_followers  \
# 0                                               1KHABYS               133
# 1                                   Diary Entry #314509               345
# 2                                         Matt Halfhill             13051
# 3                   🏁🏁🥋🏈Bishop Sycamore Starting CB🏈🥋🏁🏁               625
# 4                                          Kwame Morgan               848
# ...

# %%
df_concat.to_csv('shoe_type_franyang_oct20.csv')
