# %%
import tweepy
import time
import pandas as pd

# %%
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAGLLhgEAAAAA1aGUpgPRg1fa8jo5sgy7dpshzNg%3D6RVr4MCm9qHTe3SzL8FhxJlqwzW5qdeR9MwWZ8wwEb4FNLM8vZ',wait_on_rate_limit=True)

# %%
# Sneakers
sneakers_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'sneakers -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    sneakers_tweets.append(response)

# %%
result = []
user_dict = {}

for response in sneakers_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df = pd.DataFrame(result)

# %%
df['type'] = 'Sneakers'
df
# Out:
#                 author_id        username  author_followers  author_tweets  \
# 0     1493612427304488965         1KHABYS               125           2127
# 1                29560488      CarrieMae_               344          12283
# 2                22680919    MattHalfhill             13057            524
# 3      997270922976481282    JEFF_SON_334               605           3780
# 4               101915799     kwamemorgan               847          25434
# ...                   ...             ...               ...            ...
# 2781            465886230         pshew09                56            672
# 2782  1348396865042132992      madzfortbz               436          19529
# 2783  1553873902606004224  ShopTheDrop253                 3              2
# 2784  1477403880015151107         Edasiar               371          16217
# 2785            160783887        illiotti              2475          53961
#
#                                      author_description  \
# 0     Be ¥a $elf or Bring ¥a $hooters! 👀🎮 BYS LLC™️ ...
# 1        the devil works hard, kris jenner works harder
# 2      Founder + CEO of @nicekicks. DMs are open. sz 11
# 3     Husband, Father to a son ,COOL MF in General U...
# 4                           Follow my IG : @Kwamemorgan
# ...                                                 ...
# 2781  The amount of Chopped I watch is utterly disgu...
# 2782                            deobiverse🧵|| multistan
# 2783       Exclusive sneaker shop located in Tacoma, WA
# 2784                                    leave me alone.
# 2785  #socialmedia #media New York City\n \n\n illio...
#
#                author_location  \
# 0           Around da corner⭐️
# 1                 Brooklyn, NY
# 2                   Austin, TX
# 3               Montgomery, AL
# 4     ÜT: 38.899236,-76.797741
# ...                        ...
# 2781                      None
# 2782             she/her || 22
# 2783                      None
# 2784                yes you 👆🏾
# 2785                  278 B.Q.
#
#                                                    text  \
# 0     Privileged never paid over box price for sneakers
# 1     Trying to have a peaceful evening and at the r...
# 2     Drop sneakers at a job fair if you don’t want ...
# 3     I hate the fact that Puma ain’t got no sneaker...
# 4     @1_Bundles You know my lil buddies gone geek t...
# ...                                                 ...
# 2781  @thadbrown7 @SharpFootball I’ll bet a pair of ...
# 2782                  they got hyunjin doing sneakers 😭
# 2783  Coming soon to the Tacoma Mall #Sneakers https...
# 2784    @PaeDaBaee @cvazquez936 Give me some sneakers 😂
# 2785  #data #science #google &amp; #twitter #analyti...
#
#                     created_at  retweets  replies  likes  quote_count  \
# 0    2022-09-30 23:28:41+00:00         0        0      0            0
# 1    2022-09-30 23:21:03+00:00         0        0      0            0
# 2    2022-09-30 23:13:22+00:00        94       40    961           27
# 3    2022-09-30 22:36:38+00:00         0        0      0            0
# 4    2022-09-30 22:33:35+00:00         0        1      0            0
# ...                        ...       ...      ...    ...          ...
# 2781 2022-08-01 02:22:29+00:00         0        1      0            0
# 2782 2022-08-01 02:20:47+00:00         0        0      0            0
# 2783 2022-08-01 02:12:47+00:00         0        0      0            0
# 2784 2022-08-01 02:06:54+00:00         0        0      0            0
# 2785 2022-08-01 01:32:52+00:00         0        0      0            0
#
#           type
# 0     Sneakers
# 1     Sneakers
# 2     Sneakers
# 3     Sneakers
# 4     Sneakers
# ...        ...
# 2781  Sneakers
# 2782  Sneakers
# 2783  Sneakers
# 2784  Sneakers
# 2785  Sneakers
#
# [2786 rows x 13 columns]

# %%
# Boots
boots_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'boots -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    boots_tweets.append(response)

# %%
result = []
user_dict = {}

for response in boots_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df2 = pd.DataFrame(result)

# %%
df2['type'] = 'Boots'
df2
# Out:
#                 author_id         username  author_followers  author_tweets  \
# 0               238781995  Mr_Nonautomatic              1833          35393
# 1      873591777047052288   VigilanteWayz_                73           5624
# 2     1519061530205171712       navy80to04                54           1232
# 3                37000068         chucko24              2847          81925
# 4              2826977876     sankofa_bird              4842          23563
# ...                   ...              ...               ...            ...
# 7047             17635873  eleanoralenoraa               207           5973
# 7048           2320525095   MannyTheHooper              1564         103528
# 7049           4514169209      joyreeves23                64            381
# 7050           1293734154       StevieJPTX              2894          71537
# 7051  1198993525964247042      BadBeatsLex               576           7304
#
#                                      author_description  \
# 0                   ▬▬▬▬▬▬▬ ♞ ♛ † ♛ ♞ ▬▬▬▬▬▬   IG:Boyj_
# 1     UNF Grad Student 📚. FSW Graduate 👨🏿‍🎓. Owner o...
# 2     Retired HTC sw U.S. Navy 24 years. 5 ships. Am...
# 3     Pain is Inevitable, Suffering Is Optional  US ...
# 4     TV & Film Writer/Director/Actress. Repped @ Ar...
# ...                                                 ...
# 7047  Neither lean nor mean. She/her. Abercrombie-lo...
# 7048  just a boring guy. sometimes I paint shitty pa...
# 7049                Just the mother of two crazy kids..
# 7050  @TheRealSportDFW | ETX Broadcasting Radio Host...
# 7051                                              #SPDG
#
#                      author_location  \
# 0                        Chicago, IL
# 1     Saved under contact name Bri❤️
# 2                       Columbia, IL
# 3       iPhone: 28.097036,-82.779137
# 4                    Los Angeles, CA
# ...                              ...
# 7047                     Detroit, MI
# 7048                 San Antonio, TX
# 7049                 Douglasville ga
# 7050                       Paris, TX
# 7051                   United States
#
#                                                    text  \
# 0     me last night at bubble pop HIGH BOOTS \n http...
# 1     Mandate Spence vs Boots\nCrawford fight the go...
# 2     @JDrewsyBC My work boots, I just ordered 3 pai...
# 3     @MOmentumMoshay Dam I knew this was gonna back...
# 4     Me: “I just did a closest cleanse, I can’t sho...
# ...                                                 ...
# 7047  fighting a very real and very comical urge to ...
# 7048  I can’t believe he’s wrestling in real cowboy ...
# 7049  REDNECK HOME SECURITY SYSTEM:\n1. Buy a pair o...
# 7050  Girlfriend: “So whose bed have your boots been...
# 7051  @__TayJones_ @OfficialBNorman lol but that’s t...
#
#                     created_at  retweets  replies  likes  quote_count   type
# 0    2022-09-30 23:57:17+00:00         0        2     14            0  Boots
# 1    2022-09-30 23:52:40+00:00         0        0      0            0  Boots
# 2    2022-09-30 23:48:55+00:00         0        0      1            0  Boots
# 3    2022-09-30 23:44:36+00:00         0        1      1            0  Boots
# 4    2022-09-30 23:43:41+00:00         0        1      4            0  Boots
# ...                        ...       ...      ...    ...          ...    ...
# 7047 2022-08-01 00:40:17+00:00         0        0      2            0  Boots
# 7048 2022-08-01 00:38:04+00:00         0        0      5            0  Boots
# 7049 2022-08-01 00:34:34+00:00         0        0      0            0  Boots
# 7050 2022-08-01 00:09:31+00:00         0        0      1            0  Boots
# 7051 2022-08-01 00:06:22+00:00         0        1      0            0  Boots
#
# [7052 rows x 13 columns]

# %%
# Loafers
loafers_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'loafers -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    loafers_tweets.append(response)

# %%
result = []
user_dict = {}

for response in loafers_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df3 = pd.DataFrame(result)

# %%
df3['type'] = 'Loafers'
df3
# Out:
#                author_id         username  author_followers  author_tweets  \
# 0              197907864      Nautinole24               154           4029
# 1             3193779470      Protrending               495           3450
# 2              383627441     Lars_Griffin               519           1063
# 3     737929982018768900          oddtank               870          52587
# 4              208428580     CallMeMoprah             10230          48706
# ..                   ...              ...               ...            ...
# 234           3044590740         babymp3_               619          51546
# 235           1119877860       resipsausa              1862           3719
# 236   733432147214635008   sleepyboiMoosh              1002          55624
# 237            615790487       britsjoint               802          32797
# 238  1244838529571655687  DinahHouseFire1               121           1449
#
#                                     author_description   author_location  \
# 0                                                          Pensacola, FL
# 1    Style like a Pro™ | Where Fashion, Sports and ...       Los Angeles
# 2    An actor who wants to make it to a major marke...  Martinsville, VA
# 3                          Long Live Tayman  | he/him         Tampa, FL
# 4    ✞ • BLACK • she/her • MN • #SPED teacher • Bil...   Anishinaabewaki
# ..                                                 ...               ...
# 234                    sorry i’m not made out of sugar   planet god damn
# 235  rēs ipsa loquitur [REYS ip-suh]: Latin. The th...  Atlanta, Georgia
# 236  Just another kid from Woodlawn\n\n\nCommunity ...       Madison, WI
# 237                     live tweets from my brain | ♓︎             texas
# 238                 drag queen, connoisseur of garbage   Little Rock, AR
#
#                                                   text  \
# 0    @andykantor @nut_history You suggested action ...
# 1    We told you we would get #EliApple’s #TNF styl...
# 2    Another original knot in the dark pinstripes w...
# 3    @k_ddott them ugly ass loafers he got on his feet
# 4    @teachergrape If those loafers are from target...
# ..                                                 ...
# 234  @kennnyyya a pinboard of pictures of memories ...
# 235  Cactus Silk Loafers. Limited Edition. Availabl...
# 236                 yeah imma need those loafers lmfao
# 237                 I’ma buy these loafers idc anymore
# 238  Scrolling on Poshmark today looking for some l...
#
#                    created_at  retweets  replies  likes  quote_count     type
# 0   2022-09-30 18:16:29+00:00         0        0      0            0  Loafers
# 1   2022-09-30 01:10:12+00:00         0        0      0            0  Loafers
# 2   2022-09-29 23:32:15+00:00         0        0      0            0  Loafers
# 3   2022-09-29 18:35:58+00:00         0        0      1            0  Loafers
# 4   2022-09-29 13:05:20+00:00         0        0      1            0  Loafers
# ..                        ...       ...      ...    ...          ...      ...
# 234 2022-08-02 03:24:12+00:00         0        1      3            0  Loafers
# 235 2022-08-01 23:01:07+00:00         0        0      0            0  Loafers
# 236 2022-08-01 17:38:00+00:00         0        0      0            0  Loafers
# 237 2022-08-01 12:31:00+00:00         0        0      0            0  Loafers
# 238 2022-08-01 04:51:52+00:00         0        0      0            0  Loafers
#
# [239 rows x 13 columns]

# %%
# Business shoes
bs_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'business shoes -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    bs_tweets.append(response)

# %%
result = []
user_dict = {}

for response in bs_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df4 = pd.DataFrame(result)

# %%
df4['type'] = 'Business shoes'
df4
# Out:
#               author_id         username  author_followers  author_tweets  \
# 0   1346251451950104577  MonicaWhitman17                29           1891
# 1              49516492       BonniePuns              4987          58835
# 2            2714308257   anissagardizy8              3099           2585
# 3            2714308257   anissagardizy8              3099           2585
# 4            2714308257   anissagardizy8              3099           2585
# ..                  ...              ...               ...            ...
# 71           4044116063    LoveeeeeShay_               281          44446
# 72             36808473      kinjipscott               953          37545
# 73   889568289726312450  margaretcox2299               937          37196
# 74             16099690    FrederickMelo             13398          54944
# 75            355374842       MrNateDunn               565           1348
#
#                                    author_description        author_location  \
# 0   👻 @ Monica_leighann 910✈️585 Joseph🤞🏾 Auntie o...                   None
# 1   heart shaped ding dong and professional chef, ...        Los Angeles, CA
# 2   Tech reporter for @bostonglobe. past: @theinfo...             Boston, MA
# 3   Tech reporter for @bostonglobe. past: @theinfo...             Boston, MA
# 4   Tech reporter for @bostonglobe. past: @theinfo...             Boston, MA
# ..                                                ...                    ...
# 71                                         3-13-16 👼👼   In My Own Business 📍
# 72  I am not looking for a job or money. I never w...          Baltimore, MD
# 73  she/her/End AIPAC; WOKE IS A VERB ;Medicare 4 ...           Florida, USA
# 74  St. Paul Pioneer Press (@pioneerpress) Urban L...  St. Paul, Minneapolis
# 75  Engineering & Robotics Educator & FLL Robotics...    CTMS- Grapevine, TX
#
#                                                  text  \
# 0   Any time a box come in the house my man thinks...
# 1   going as tom cruise in risky business for Hall...
# 2   Bennett Collen, a @BostonCollege alum, brings ...
# 3   Endstate embeds a chip into the tongue of ever...
# 4   Meet the unlikely duo that started @endstate, ...
# ..                                                ...
# 71  UPS got me fucked up. My son shoes better be h...
# 72  @BaltoSpectator You know he worked hard in his...
# 73  @mcgirty69 @HorseSense25 @podiatristdon @Deedo...
# 74  The Minneapolis/St. Paul Business Journal is l...
# 75  @baalbakd @DavidTadRussell @NicholasFerroni @a...
#
#                   created_at  retweets  replies  likes  quote_count  \
# 0  2022-09-29 20:41:24+00:00         0        0      1            0
# 1  2022-09-28 16:57:03+00:00         1        1     23            0
# 2  2022-09-28 00:27:29+00:00         1        1      4            0
# 3  2022-09-28 00:12:30+00:00         0        1      3            0
# 4  2022-09-28 00:04:30+00:00         9        2     24            0
# ..                       ...       ...      ...    ...          ...
# 71 2022-08-04 22:02:22+00:00         0        0      0            0
# 72 2022-08-04 12:17:37+00:00         0        1      1            0
# 73 2022-08-02 03:53:20+00:00         0        0      0            0
# 74 2022-08-01 20:08:08+00:00         3        1      2            1
# 75 2022-08-01 02:21:50+00:00         0        1      1            0
#
#               type
# 0   Business shoes
# 1   Business shoes
# 2   Business shoes
# 3   Business shoes
# 4   Business shoes
# ..             ...
# 71  Business shoes
# 72  Business shoes
# 73  Business shoes
# 74  Business shoes
# 75  Business shoes
#
# [76 rows x 13 columns]

# %%
# Slippers
slippers_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'slippers -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    slippers_tweets.append(response)

# %%
result = []
user_dict = {}

for response in slippers_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df5 = pd.DataFrame(result)
df5['type'] = 'Slippers'
df5
# Out:
#                author_id         username  author_followers  author_tweets  \
# 0              238842169           emhed_               586          45670
# 1    1484605226220982277  intern3tthottie              1444            860
# 2             1454713914    DedeVotesBlue              9078          27289
# 3               81259499         mzd1mple                24           1910
# 4     903094879412035584      Sarah_RN_WI               499          23536
# ..                   ...              ...               ...            ...
# 650  1547059238924853248       sa61740585                24            134
# 651  1549659659916947456     Sali82955130                 1            101
# 652             90895400   StanleyRoberts             26180          56507
# 653  1462799619134533632         CuhCRYST               138           2785
# 654   734900756784914432           beeljo               654          19991
#
#                                     author_description  \
# 0    Communication is key. Bluegrass music makes my...
# 1    the names JIZZ short for Jizzel, welcum to my ...
# 2    I’m 😯#Prochoice - Worried about the future of ...
# 3    I live in hometown of #MissyElliot | forever y...
# 4    RN, Mama, Tuberous Sclerosis Complex, Intracta...
# ..                                                 ...
# 650  Success is standing up more than falling down ...
# 651  Reality cannot defeat us, it only makes us str...
# 652  Executive Producer/Consultant. Mentioned in @R...
# 653  Not new to twitter old account got banned.. “J...
# 654  Trump supporters: even if the info wasn't clas...
#
#                 author_location  \
# 0                    Auburn, AL
# 1                   Orlando, FL
# 2         Portland/Breckenridge
# 3                 Virginia, USA
# 4                Wisconsin, USA
# ..                          ...
# 650                          SF
# 651             Los Angeles, CA
# 652  37.7749° N, 122.4194° W 🌊🦀
# 653                 Memphis, TN
# 654                       Earth
#
#                                                   text  \
# 0    @itweetedURchick So trueee. Sometimes I take s...
# 1    It’s a beautiful day to wear UGGS Slippers 🍂 h...
# 2                             @MadScientistFF Slippers
# 3    @hourIyng #SUGAatNBAJapan #SUGA came out reall...
# 4    @BertoInPublic I worked at a discount store wh...
# ..                                                 ...
# 650  I like these ivory slippers very much. I want ...
# 651  I like these ivory slippers very much. I want ...
# 652  @beatcop4life @RealByronAllen @nigeldick @sinb...
# 653  @1AB1_ Have house slippers at the door to replace
# 654  @donwinslow @JohnFetterman @DrOz I wouldn't ca...
#
#                    created_at  retweets  replies  likes  quote_count      type
# 0   2022-09-30 21:50:38+00:00         0        0      1            0  Slippers
# 1   2022-09-30 21:46:43+00:00         0        0      3            0  Slippers
# 2   2022-09-30 20:51:52+00:00         0        0      0            0  Slippers
# 3   2022-09-30 18:40:17+00:00         0        0      0            0  Slippers
# 4   2022-09-30 15:58:36+00:00         0        0      1            0  Slippers
# ..                        ...       ...      ...    ...          ...       ...
# 650 2022-08-01 23:52:04+00:00         0        0      0            0  Slippers
# 651 2022-08-01 23:49:08+00:00         0        0      0            0  Slippers
# 652 2022-08-01 23:23:40+00:00         0        1      0            0  Slippers
# 653 2022-08-01 19:02:05+00:00         0        1      1            0  Slippers
# 654 2022-08-01 14:40:34+00:00         0        0      1            0  Slippers
#
# [655 rows x 13 columns]

# %%
# Sandals
sandals_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'sandals -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    sandals_tweets.append(response)

# %%
result = []
user_dict = {}

for response in sandals_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df6 = pd.DataFrame(result)
df6['type'] = 'Sandals'
df6
# Out:
#                 author_id         username  author_followers  author_tweets  \
# 0              3342189372      ashzamorano               636           1478
# 1                22098235   MelodyOrganics               904          20679
# 2               259148967  andrewpelletier               369           7158
# 3     1489348395017781252  dontbeweirdtome               125           5620
# 4              3505560323  NiteniteMelissa              7310         640497
# ...                   ...              ...               ...            ...
# 1038            304179492        blewis823              8126         119218
# 1039  1001178515256107009   ashtagnofilter               344          16220
# 1040  1539087986461114368     MouldofSteel                14            429
# 1041           1352673810    Kirbadactal23               129          42471
# 1042            231979119    CaramelFrost_              3059         270550
#
#                                      author_description  \
# 0
# 1      your edge control doesn’t work on me honey 🧘🏾‍♀️
# 2     songwriter/composer. producer. teacher REBORN ...
# 3                     ⚠️ you don’t have to follow me ⚠️
# 4     Elizabeth Warren is my spirit animal #LPN #Jer...
# ...                                                 ...
# 1038  No DMs, Still play Sims, 4ever Love Prince. St...
# 1039  just an irish girl from jersey city ⭐️ profess...
# 1040                                      eBay Reseller
# 1041
# 1042  The price we pay for being ourselves is worth ...
#
#                  author_location  \
# 0                           None
# 1     Right Place, Right Time ❤️
# 2        Los Angeles via Chicago
# 3                           None
# 4                           None
# ...                          ...
# 1038               United States
# 1039               Thunder Road
# 1040                   Wisconsin
# 1041                        None
# 1042                Stamford, CT
#
#                                                    text  \
# 0                   every dad in yuma owns reef sandals
# 1     🎶 Thinking about being myself for Halloween th...
# 2     @columnatedrunes- did you ever get those huara...
# 3     i can't wait to get to super OG status so i ca...
# 4     @SykesCharlie @RadioFreeTom @tedcruz Three of ...
# ...                                                 ...
# 1038  Gave me something to think about. For real.\n\...
# 1039  Minus the sandals this is a classic Papa outfi...
# 1040  Check out Nike Youth Boy's Kawa Slip On Slide ...
# 1041     2 and a half hours until adidas sandals August
# 1042  For my outfit for Saturday and some cute sanda...
#
#                     created_at  retweets  replies  likes  quote_count     type
# 0    2022-09-30 22:28:36+00:00         1        0      1            0  Sandals
# 1    2022-09-30 22:04:34+00:00         0        0      0            0  Sandals
# 2    2022-09-30 19:15:31+00:00         0        1      0            0  Sandals
# 3    2022-09-30 18:41:30+00:00         0        2      2            0  Sandals
# 4    2022-09-30 17:42:53+00:00         0        0      3            0  Sandals
# ...                        ...       ...      ...    ...          ...      ...
# 1038 2022-08-01 03:50:54+00:00         1        3      6            0  Sandals
# 1039 2022-08-01 02:43:27+00:00         0        0      0            0  Sandals
# 1040 2022-08-01 02:39:01+00:00         0        0      2            0  Sandals
# 1041 2022-08-01 01:34:39+00:00         0        0      0            0  Sandals
# 1042 2022-08-01 00:51:10+00:00         0        0      1            1  Sandals
#
# [1043 rows x 13 columns]

# %%
df_concat = pd.concat([df, df2, df3, df4, df5, df6])

# %%
df_concat
# Out:
#                 author_id        username  author_followers  author_tweets  \
# 0     1493612427304488965         1KHABYS               125           2127
# 1                29560488      CarrieMae_               344          12283
# 2                22680919    MattHalfhill             13057            524
# 3      997270922976481282    JEFF_SON_334               605           3780
# 4               101915799     kwamemorgan               847          25434
# ...                   ...             ...               ...            ...
# 1038            304179492       blewis823              8126         119218
# 1039  1001178515256107009  ashtagnofilter               344          16220
# 1040  1539087986461114368    MouldofSteel                14            429
# 1041           1352673810   Kirbadactal23               129          42471
# 1042            231979119   CaramelFrost_              3059         270550
#
#                                      author_description  \
# 0     Be ¥a $elf or Bring ¥a $hooters! 👀🎮 BYS LLC™️ ...
# 1        the devil works hard, kris jenner works harder
# 2      Founder + CEO of @nicekicks. DMs are open. sz 11
# 3     Husband, Father to a son ,COOL MF in General U...
# 4                           Follow my IG : @Kwamemorgan
# ...                                                 ...
# 1038  No DMs, Still play Sims, 4ever Love Prince. St...
# 1039  just an irish girl from jersey city ⭐️ profess...
# 1040                                      eBay Reseller
# 1041
# 1042  The price we pay for being ourselves is worth ...
#
#                author_location  \
# 0           Around da corner⭐️
# 1                 Brooklyn, NY
# 2                   Austin, TX
# 3               Montgomery, AL
# 4     ÜT: 38.899236,-76.797741
# ...                        ...
# 1038             United States
# 1039             Thunder Road
# 1040                 Wisconsin
# 1041                      None
# 1042              Stamford, CT
#
#                                                    text  \
# 0     Privileged never paid over box price for sneakers
# 1     Trying to have a peaceful evening and at the r...
# 2     Drop sneakers at a job fair if you don’t want ...
# 3     I hate the fact that Puma ain’t got no sneaker...
# 4     @1_Bundles You know my lil buddies gone geek t...
# ...                                                 ...
# 1038  Gave me something to think about. For real.\n\...
# 1039  Minus the sandals this is a classic Papa outfi...
# 1040  Check out Nike Youth Boy's Kawa Slip On Slide ...
# 1041     2 and a half hours until adidas sandals August
# 1042  For my outfit for Saturday and some cute sanda...
#
#                     created_at  retweets  replies  likes  quote_count  \
# 0    2022-09-30 23:28:41+00:00         0        0      0            0
# 1    2022-09-30 23:21:03+00:00         0        0      0            0
# 2    2022-09-30 23:13:22+00:00        94       40    961           27
# 3    2022-09-30 22:36:38+00:00         0        0      0            0
# 4    2022-09-30 22:33:35+00:00         0        1      0            0
# ...                        ...       ...      ...    ...          ...
# 1038 2022-08-01 03:50:54+00:00         1        3      6            0
# 1039 2022-08-01 02:43:27+00:00         0        0      0            0
# 1040 2022-08-01 02:39:01+00:00         0        0      2            0
# 1041 2022-08-01 01:34:39+00:00         0        0      0            0
# 1042 2022-08-01 00:51:10+00:00         0        0      1            1
#
#           type
# 0     Sneakers
# 1     Sneakers
# 2     Sneakers
# 3     Sneakers
# 4     Sneakers
# ...        ...
# 1038   Sandals
# 1039   Sandals
# 1040   Sandals
# 1041   Sandals
# 1042   Sandals
#
# [11851 rows x 13 columns]

# %%
df_concat.to_csv('shoe_type_franyang_oct1.csv')
