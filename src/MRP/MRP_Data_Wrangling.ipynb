# %%
#Loading lib
import pandas as pd
import numpy as np

# %% [markdown]
# #Data Wrangling

# %%
#Loading datasets - remember to drop in the survey csvs before proceeding
df = pd.read_csv("Reebok_Survey_Econded.csv")
df
# Out:
#     Age  Gender     Region States
# 0     3       2  Northeast     PA
# 1     4       1   Midwsest     WI
# 2     4       2      South     TX
# 3     4       1   Midwsest     MI
# 4     4       2   Midwsest     IL
# ..  ...     ...        ...    ...
# 69    3       2  Northeast     MA
# 70    4       1       West     CA
# 71    4       2   Midwsest     IL
# 72    4       2      South     TN
# 73    3       2       West     CA
#
# [74 rows x 4 columns]

# %%
#Creating unique dataframe containing frequency - simulation
unique_df = (df.groupby(['Age', 'Gender', 'States','Region'])
                           .States
                           .agg(
                               Count = 'size'
                           )
                           .reset_index())

# %%
#Twitter data, n = shows the frequency in which the combination of independent variables appeared
unique_df
# Out:
#     Age  Gender States     Region  Count
# 0     2       1     CA       West      1
# 1     2       1     FL      South      1
# 2     2       1     IL   Midwsest      1
# 3     2       1     MI   Midwsest      1
# 4     2       1     TN      South      1
# 5     2       2     OK      South      1
# 6     3       1     IN   Midwsest      1
# 7     3       1     VA      South      1
# 8     3       2     CA       West      3
# 9     3       2     GA      South      1
# 10    3       2     IL   Midwsest      2
# 11    3       2     LA      South      1
# 12    3       2     MA  Northeast      1
# 13    3       2     NY  Northeast      2
# 14    3       2     OR       West      1
# 15    3       2     PA  Northeast      1
# 16    3       2     SC      South      1
# 17    3       2     TX      South      1
# 18    3       3     MO   Midwsest      1
# 19    4       1     AK       West      1
# 20    4       1     CA       West      4
# 21    4       1     CO       West      1
# ...

# %%
#Checking reduction in data size
unique_df.shape[0] / df.shape[0]

#use Survey data's preference by state
# Out:
# 0.6486486486486487

# %%
#Writing to CSV - remember to download
unique_df.to_csv('Reebok_PS.csv',index = False)
