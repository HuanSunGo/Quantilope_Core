# %% [markdown]
# # Code snippet of fetching tweets from Twitter API

# %%
# import libraries 
import matplotlib.pyplot as plt 
from twarc import Twarc2

# %%
# change your credentials here 
client = Twarc2(bearer_token='AAAAAAAAAAAAAAAAAAAAAI87hgEAAAAAEg9cOWXo0WeIA1I8cQ9cp4sVgPI%3DoLXzJeLW9svZ9uni7ANWJ42zsog2oSoMpr7ZIKwuNXbwQ8eZMq')

# input the query info
query = 'midterm'

# apply the query
search_results = client.counts_recent(query = query, granularity = 'day')

# the twarc returns results in pages, where the counts info is stored in the first page 
for page in search_results:
    data = page['data']
    break 

# create list to store 
day = []
tweet_counts = []
for d in data: 
    day.append(d['start'][:10])
    tweet_counts.append(d['tweet_count'])

# visualize the result 
fig,ax = plt.subplots()
ax.plot(day,tweet_counts)
plt.style.use('bmh')
plt.show()
