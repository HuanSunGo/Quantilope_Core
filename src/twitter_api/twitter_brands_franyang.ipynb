# %%
import tweepy
import time
import pandas as pd

# %%
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAGLLhgEAAAAA1aGUpgPRg1fa8jo5sgy7dpshzNg%3D6RVr4MCm9qHTe3SzL8FhxJlqwzW5qdeR9MwWZ8wwEb4FNLM8vZ',wait_on_rate_limit=True)

# %%
# Puma
puma_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'puma -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    puma_tweets.append(response)

# %%
result = []
user_dict = {}

for response in puma_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df = pd.DataFrame(result)

# %%
df['brand'] = 'Puma'
df
# Out:
#                author_id         username  author_followers  author_tweets  \
# 0    1549441622231900164     SuchitaHedau               353           1465
# 1     997270922976481282     JEFF_SON_334               606           3780
# 2               69133413    tarsismenezes               391          34992
# 3              508551405  My_business_man               663          18657
# 4               66769124    THIAGAOAGUIAR              1530          49626
# ..                   ...              ...               ...            ...
# 737            347613843    derryl_golfer              1827          24421
# 738           2669912101   SheKnowsSports             16240          54054
# 739            346769869     StripeyMiata              1852          48178
# 740             65851268      MsQueenMona               433          27090
# 741           2777344511  bryantgardner86               401          10026
#
#                                     author_description  \
# 0
# 1    Husband, Father to a son ,COOL MF in General U...
# 2                                             BBBholic
# 3    This life is 100% your responsibility, so know...
# 4    Paulistano , Sobrevivente ! Enquanto meu coraç...
# ..                                                 ...
# 737  @inland_sports Senior Writer & @wachoopsdigest...
# 738  @espn Sr. SM Specialist / WNBA reporter • @con...
# 739                     It's not time to make a change
# 740  Manager|Tour Manager Order your favorite desse...
# 741  🏁 Single Dad living in Charlotte. RIP Pa Vang....
#
#                author_location  \
# 0                         None
# 1               Montgomery, AL
# 2              Los Angeles, CA
# 3           Free in the World
# 4                Weehawken, NJ
# ..                         ...
# 737                 Menifee,CA
# 738               Hartford, CT
# 739  Lisburn, Northern Ireland
# 740              ATL|MIA|CHI 📍
# 741              Pineville, NC
#
#                                                   text  \
# 0                          @kuchbhishubhh Puma shoes 😮
# 1    I hate the fact that Puma ain’t got no sneaker...
# 2    @slashviolence @PUMA @neymarjr @pumafootball Y...
# 3    @i95Bully @ForeverKnicks_ Nah. Puma store on 4...
# 4    Extremely disappointed PUMA . The LGBTQA+ suff...
# ..                                                 ...
# 737  https://t.co/quM8ndfbY8 \n\nIt's Queens Court ...
# 738  @Vantastix @PUMA It hasn’t dropped yet. It doe...
# 739  @matt_kempez @MttRbnsn @KiaUKPR Reminds me of ...
# 740  Niggas stop coming to airport w/ your fresh De...
# 741                      #puma is getting all my money
#
#                    created_at  retweets  replies  likes  quote_count brand
# 0   2022-09-30 23:59:39+00:00         0        0      1            0  Puma
# 1   2022-09-30 22:36:38+00:00         0        0      0            0  Puma
# 2   2022-09-30 22:05:04+00:00         0        0      0            0  Puma
# 3   2022-09-30 17:33:24+00:00         0        1      1            0  Puma
# 4   2022-09-30 16:08:20+00:00         0        0      3            0  Puma
# ..                        ...       ...      ...    ...          ...   ...
# 737 2022-08-01 13:31:28+00:00         3        0      7            0  Puma
# 738 2022-08-01 13:20:08+00:00         0        1      2            0  Puma
# 739 2022-08-01 11:56:37+00:00         0        0      0            0  Puma
# 740 2022-08-01 11:54:37+00:00         0        0      0            0  Puma
# 741 2022-08-01 02:58:52+00:00         0        0      0            0  Puma
#
# [742 rows x 13 columns]

# %%
# Toms
toms_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'toms -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    toms_tweets.append(response)

# %%
result = []
user_dict = {}

for response in toms_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df2 = pd.DataFrame(result)

# %%
df2['brand'] = 'Toms'
df2
# Out:
#       author_id         username  author_followers  author_tweets  \
# 0    4347892641     biblicalputa               536          25497
# 1     915901424     BradyOltmans              1369          15617
# 2    2714500055      AndresOnAir               374           5996
# 3    1357774872     chazmatazztr               188           3230
# 4    1414684496  everyEarthquake             27973         753853
# ..          ...              ...               ...            ...
# 691  1414684496  everyEarthquake             27973         753853
# 692    50706690            511NY              3989        5804335
# 693    50706690            511NY              3989        5804335
# 694  1293734154       StevieJPTX              2895          71537
# 695    16381945      eton_rifles               826          44441
#
#                                     author_description  \
# 0    detroit via jersey so you KNOW my pussy is mut...
# 1    Nebraska football reporter @HailVarsity. corgi...
# 2    🎙PxP Broadcaster for Colby, KS Sports - KRDQ 1...
# 3    Chazmatazz Formalwear of Toms River offers mor...
# 4    Tweeting every earthquake occurrence reported ...
# ..                                                 ...
# 691  Tweeting every earthquake occurrence reported ...
# 692  Traffic & transit updates for all of New York ...
# 693  Traffic & transit updates for all of New York ...
# 694  @TheRealSportDFW | ETX Broadcasting Radio Host...
# 695  Single, no kids, Enjoy sports and video games....
#
#             author_location  \
# 0               Detroit, MI
# 1               Lincoln, NE
# 2                 Colby, KS
# 3           Toms River, NJ
# 4                     Earth
# ..                      ...
# 691                   Earth
# 692          New York State
# 693          New York State
# 694               Paris, TX
# 695  Tiverton, Rhode Island
#
#                                                   text  \
# 0    @papayessir yes the existence of toms river, n...
# 1    Weekend reading for you.\n\n@DrakeKeeler’s tak...
# 2    Wish I could be there! Miss calling @TommieMHo...
# 3    Just arrived to Chazmatazz Formalwear of Toms ...
# 4    USGS reports a M1.23 earthquake, 17km E of Tom...
# ..                                                 ...
# 691  USGS reports a M1.71 earthquake, 37km N of Tom...
# 692  Construction on #GardenStateParkway NB from So...
# 693  Construction on #GardenStateParkway SB from So...
# 694  People like Tom enable people like Watson in o...
# 695  I'm at Toms Market in Tiverton, RI https://t.c...
#
#                    created_at  retweets  replies  likes  quote_count brand
# 0   2022-09-30 23:18:02+00:00         0        0      2            0  Toms
# 1   2022-09-30 23:09:33+00:00         2        0      3            0  Toms
# 2   2022-09-30 20:37:56+00:00         0        0      0            0  Toms
# 3   2022-09-30 19:45:14+00:00         0        0      0            0  Toms
# 4   2022-09-30 17:29:35+00:00         1        0      5            0  Toms
# ..                        ...       ...      ...    ...          ...   ...
# 691 2022-08-01 16:26:50+00:00         1        0      3            0  Toms
# 692 2022-08-01 14:39:46+00:00         0        0      0            0  Toms
# 693 2022-08-01 14:37:56+00:00         0        0      0            0  Toms
# 694 2022-08-01 12:39:38+00:00         2        5     15            1  Toms
# 695 2022-08-01 01:36:51+00:00         0        0      0            0  Toms
#
# [696 rows x 13 columns]

# %%
# Keds
keds_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'keds -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    keds_tweets.append(response)

# %%
result = []
user_dict = {}

for response in keds_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df3 = pd.DataFrame(result)

# %%
df3['brand'] = 'Keds'
df3
# Out:
#               author_id         username  author_followers  author_tweets  \
# 0              29560488       CarrieMae_               344          12283
# 1    820770788991115266       JRaclawski               121          10672
# 2    946917486380879872    preppyliberty              4076           9337
# 3   1027241907884314624    MCoachtoliver               386           1995
# 4              21122791        vtbrittlj               249          16751
# 5    820770788991115266       JRaclawski               121          10672
# 6   1449223402590457859   AndreClaudio_1               105            570
# 7            2279728812  KimberlynCarter               854          31119
# 8            1239505812       Narfnampil              3913          35445
# 9              38347394     CallmeTinaja              1148          15397
# 10            183214800   footiusmaximus              1467          32474
# 11  1081794314982883328    Chris_Boudrie               356          11451
# 12  1535385878335463430   MekitaMichelle                51            252
# 13  1264995750317965312   mom2max96_lisa              1714          46987
# 14   739082620898775040   kellycsteacher               261            448
# 15            105017546       fosterhood              4786          19660
# 16   873550650604494848  haitiprinceshit             10541            937
# 17            587437673       mskvarla36              2879         117069
# 18            165595246            KSEAC                40            706
# 19            165595246            KSEAC                40            706
# 20           4855815293        GrammaGaz             32330          78962
# 21            370403181         ernunnos               330          18858
# 22            191091544    WheredJasonGo              1021          63836
# 23             39865883           _Ctina               249          11601
# 24  1423605563028561925     floridaEdMom              2776          12070
# 25             40235502          damwop2              1426          25020
# 26           1663892186       LoriCoxHan               601           2458
# 27             18773718        ZODIAC_MF             22163          93125
# 28           1239505812       Narfnampil              3913          35445
# 29            412712711         LOSOLINA              1888          58526
# 30           2366444442     21ForLifeHOF               654           8986
# 31             36903980         pooldoc1               676          12052
# 32            412712711         LOSOLINA              1888          58526
# 33            151935894         Joanntol               106           2968
# 34  1447268453463830528       JheyCintra                12            437
# 35  1521869137462521856          Nanc733                 4            349
# 36            467372270  sammiethefoodie               581          16763
# 37           1160805510    The_LoganFoxx               382          12391
# 38           1160805510    The_LoganFoxx               382          12391
# 39            885391592   ShaynaJaskolka              1797          16994
# 40           2366444442     21ForLifeHOF               654           8986
#
#                                    author_description       author_location  \
# 0      the devil works hard, kris jenner works harder          Brooklyn, NY
# 1   MUSTANG ci-guy-sometimes you can’t just”get al...                  None
# 2   SAHM, Libertarian Lite, Lover of books, bourbo...            The South
# 3   Assistant Principal at Brenham High School, Co...                  None
# 4   kick back and get high on the livin part of li...          Richmond, VA
# 5   MUSTANG ci-guy-sometimes you can’t just”get al...                  None
# 6   Staff writer @sourcingjournal. Pop culture & f...          New York, NY
# 7                        #BeFearless #BrandDomination           Atlanta, GA
# 8   Tax/poverty law prof/LLM/MBA/CPA @UNLVLaw All ...         Las Vegas, NV
# 9   Community Crisis Chaplain; First Responder; Me...                   NYC
# 10  Enjoys Phishing, long talks about the Grateful...               Fenario
# 11  Introverted Detroit sports fan. I run the fine...            Warren, MI
# 12  Truth, Justice and The American way matter to ...       New York State
# 13  Native New Yorker 🗽Proud Mom| Travel lover 💚🍀 ...       Los Angeles, CA
# 14  Curriculum Program Manager | EdTech | Leadersh...          Lakeland, FL
# 15  Adoptee turned foster, now adoptive parent (20...          New York, NY
# 16  6’4 & a real life ZOE 😈🔝 tier IRL💯 dis luh blu...           Atlanta, GA
# 17  PhD in entomology, professor of insect ID.  Co...      Port Matilda, PA
# 18  Lover of all things J Crew, Bryan Adams, and w...          Chehalis, WA
# 19  Lover of all things J Crew, Bryan Adams, and w...          Chehalis, WA
# 20  Mom×2, Grandma×3, Retired, Road Tripper, Theat...        Buena Park, CA
# 21                              Semi-cultured redneck           Phoenix, AZ
# 22  Loud music, baked goods, and zines. Chris Corn...           Seattle, WA
# 23  (king Chris👸🏻) mom of L&V, asst. PE coach to a...            Texas girl
# 24  public Ed advocate and prolific Letter to the ...           Orlando, FL
# 25  A beautiful mess ♎️ wife, mom, Nonna, smart As...           Norfolk, VA
# 26  Political scientist; presidency scholar; SF Gi...            Orange, CA
# 27       "ZODIACS RED FLAG CHALLENGES THE HEAVENS..."           OLD DETROIT
# 28  Tax/poverty law prof/LLM/MBA/CPA @UNLVLaw All ...         Las Vegas, NV
# 29                                                                     None
# 30  Husband | Father | Analyst | Mentor HOF Induct...                  None
# 31  Host... SNR monthly recap Show , Host Jungle p...  spring branch, texas
# 32                                                                     None
# 33  Marshall Rams Football mom!! StMU Volleyball m...       San Antonio, TX
# 34                                            🤍✨ 🇺🇸🇧🇷      West Chester, PA
# 35                                                                     None
# 36  Taco Enthusiast l Former NYer trying to find g...         Davenport, FL
# 37  The only thing kindness can hurt is pride. ♌️ ...            Chromatica
# 38  The only thing kindness can hurt is pride. ♌️ ...            Chromatica
# 39  Clipboard gal! Now: @Schneider4IL10 📋 Then: @f...           Chicago, IL
# 40  Husband | Father | Analyst | Mentor HOF Induct...                  None
#
#                                                  text  \
# 0   Trying to have a peaceful evening and at the r...
# 1   @Christinethequ2 @BigJoeBastardi EXACTLY… no g...
# 2   @HeatherIsUnsane They’re not terrible but if I...
# 3   When the hubs surprises you with some fun Frid...
# 4   Side note: these girls in the bar with their c...
# 5   @MaeNorth13 yea.. and the Keds canvas high top...
# 6   @Keds Makes Its Luxury Debut With NYFW @ALTUZA...
# 7                          @keds_economist Thank You!
# 8   @CCP_is_satan @keds_economist Actually it does...
# 9   @a_resoundingmeh @Hoyden_Heidi @libsoftiktok S...
# 10             @Super70sSports Better than pro keds 😂
# 11    @IffyTheDopester I had Keds in grade school lol
# 12  @BigKutta1 @NikkiHaley I once wore Keds until ...
# 13  @LouakaGhost @AlTheBoss03 @Yankees I wear thes...
# 14  Lovely walk in @AudubonNature Audubon Park thi...
# 15  @RCMAuthor That white shoe paint we kept wipin...
# 16  THAT BITCH POP OUT WIT A HELMET ON HER HEAD, B...
# 17  Grant proposal submitted! Hopefully it's funde...
# 18  @katespadeny will you release a Fall/Winter li...
# 19  @RiflePaperCo will there be a Fall/Winter 22 @...
# 20  @JewishResister @FrancisWegner I think they ar...
# 21  @DempMcgee In Keds and tube socks.\n\nhttps://...
# 22  @LucretianAnimus “Why is this cool person fuck...
# 23  I had a runner today! The way I ran after this...
# 24  AND THEN YOU HAVE A ROUND OF WHAT THEY CALL “I...
# 25  @Keds aren’t just for kids. https://t.co/KAgzN...
# 26  @cconrymurray Keds. Lots of cute styles. I use...
# 27  @ChaseFailey MAYBE FLASH BACK TO HIS CHILDHOOD...
# 28  @keds_economist @HilaryHoynes Yup, and they ar...
# 29  @edubskii lmaooooooooo I like ugly men too, bu...
# 30  @EdwinFi94733275 @MikeTaylorShow @for_keds @bi...
# 31  @rnrautoglass @MikeTaylorShow @for_keds @salar...
# 32  @edubskii yea….. lol Edan likes guys that wear...
# 33  @MikeTaylorShow “You ‘member”, “It’s for the K...
# 34                                 @gringaixx Keds ♥️
# 35  @nozkcb @JDCocchiarella DAM BUCKLE UP, I THINK...
# 36  I need shoes for my Summer Nights Sandy costum...
# 37  Keds are at the concert safe &amp; sound. well...
# 38  dropping the keds off at @theweeknd concert. H...
# 39  @begyourgarden For sneakers, on the higher pri...
# 40  @for_keds @MikeTaylorShow Any word on a date f...
#
#                   created_at  retweets  replies  likes  quote_count brand
# 0  2022-09-30 23:21:03+00:00         0        0      0            0  Keds
# 1  2022-09-29 04:37:33+00:00         0        0      0            0  Keds
# 2  2022-09-25 01:18:29+00:00         0        0      0            0  Keds
# 3  2022-09-23 11:29:08+00:00         0        0     13            0  Keds
# 4  2022-09-22 00:34:09+00:00         0        3      6            0  Keds
# 5  2022-09-18 00:43:50+00:00         0        0      1            0  Keds
# 6  2022-09-14 19:30:48+00:00         0        0      0            0  Keds
# 7  2022-09-14 15:57:30+00:00         0        0      0            0  Keds
# 8  2022-09-14 09:50:43+00:00         0        1      1            0  Keds
# 9  2022-09-14 01:28:31+00:00         0        0      0            0  Keds
# 10 2022-09-10 15:36:53+00:00         0        2      3            0  Keds
# 11 2022-09-09 22:46:56+00:00         0        0      0            0  Keds
# 12 2022-09-08 12:40:10+00:00         0        0      1            0  Keds
# 13 2022-09-08 03:28:06+00:00         0        0      0            0  Keds
# 14 2022-09-07 22:03:02+00:00         0        0      4            0  Keds
# 15 2022-09-03 23:39:47+00:00         0        0      3            0  Keds
# 16 2022-09-01 20:38:24+00:00         0        0      0            0  Keds
# 17 2022-09-01 20:11:13+00:00         1        1     16            0  Keds
# 18 2022-08-25 19:26:41+00:00         0        0      0            0  Keds
# 19 2022-08-25 19:25:12+00:00         0        2      0            0  Keds
# 20 2022-08-22 05:12:38+00:00         0        1      3            0  Keds
# 21 2022-08-20 21:16:16+00:00         0        0      1            0  Keds
# 22 2022-08-18 23:36:02+00:00         0        0      3            0  Keds
# 23 2022-08-18 23:22:31+00:00         0        0      1            0  Keds
# 24 2022-08-18 21:06:29+00:00         0        0      2            0  Keds
# 25 2022-08-18 12:22:06+00:00         0        0      1            0  Keds
# 26 2022-08-14 18:17:47+00:00         0        1      4            0  Keds
# 27 2022-08-13 14:06:50+00:00         0        2     28            0  Keds
# 28 2022-08-13 01:06:10+00:00         0        0      3            0  Keds
# 29 2022-08-12 03:07:32+00:00         0        0      0            0  Keds
# 30 2022-08-12 01:39:40+00:00         4        1     15            0  Keds
# 31 2022-08-11 22:20:20+00:00         1        0      3            0  Keds
# 32 2022-08-11 17:06:11+00:00         0        0      0            0  Keds
# 33 2022-08-09 18:14:59+00:00         0        0      3            0  Keds
# 34 2022-08-09 17:53:18+00:00         0        0      0            0  Keds
# 35 2022-08-09 15:05:01+00:00         0        1      0            1  Keds
# 36 2022-08-07 18:42:40+00:00         0        0      2            0  Keds
# 37 2022-08-07 01:19:28+00:00         0        0      1            0  Keds
# 38 2022-08-07 00:20:10+00:00         0        0      3            1  Keds
# 39 2022-08-02 21:40:20+00:00         0        1      1            0  Keds
# 40 2022-08-01 14:07:13+00:00         0        2      4            0  Keds

# %%
# Allbirds
allbirds_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'allbirds -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    allbirds_tweets.append(response)

# %%
result = []
user_dict = {}

for response in allbirds_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df4 = pd.DataFrame(result)

# %%
df4['brand'] = 'Allbirds'
df4
# Out:
#      author_id        username  author_followers  author_tweets  \
# 0     19733647      GroveAyers              1537          24857
# 1    175828541     BrentonPoke               588          49253
# 2    233022380        VeraMF11               163           9354
# 3     18649433      lemichiiii               461          15215
# 4   2696296728  WilliamByrdUSA               938           8897
# ..         ...             ...               ...            ...
# 71    34129632          DPT2Go              4583          24142
# 72  2939996287        253Coble                52           1202
# 73    40507629          Bauzen              1711          92599
# 74    80341837       Inderoath               180           6845
# 75    14842636        Katadhin             30388          45889
#
#                                    author_description  \
# 0   Grove. Amalgamist. @UOsojc alum, @Brkfldproprt...
# 1   CS grad student, science fiction fan. Voraciou...
# 2   Non-profit worker and cat mom. Former teacher ...
# 3                              sensitive bore she/her
# 4   Car stuff @TheHooniverse, @OutMotorsports, @Ri...
# ..                                                ...
# 71  🎓 🎙 Founder @ConcussionCornr ® Academy & Podca...
# 72                 Father, husband, sneakerhead, etc.
# 73  Photographer • Rare Watch Collector • TBI surv...
# 74  Twitch Affiliate | YT Content Creator | Fitnes...
# 75  Mary Catherine's Dad & Mary Shannon's Husband,...
#
#                    author_location  \
# 0   en route       Mostly: Seattle
# 1                      Lansing, MI
# 2                   Washington, DC
# 3                  gainesville, fl
# 4                    Virginia, USA
# ..                             ...
# 71                    New York, NY
# 72                      Tacoma, WA
# 73      Upper West Side, Manhattan
# 74                  Washington, DC
# 75                     Raleigh, NC
#
#                                                  text  \
# 0   @sprunty2000 @CharityMiles @NWParkinsons Allbi...
# 1   @Allbirds is it possible to put these in the w...
# 2   @Allbirds Allbirds team, I ordered a pair of s...
# 3   should i buy some allbirds shoes? dad @aliewar...
# 4    @NavigationDeck Nah it was some @Allbirds shoes!
# ..                                                ...
# 71                  @Lentini_PT Love my @Allbirds 👟 🎉
# 72  @sockjig @julycreps Shit looks like some Allbi...
# 73  @mcleandavissund @RBReich I never owned a pair...
# 74  I wasn’t sure how I’d like these but damn they...
# 75  I wonder if @Allbirds SWOT analysis includes ‘...
#
#                   created_at  retweets  replies  likes  quote_count     brand
# 0  2022-09-30 02:10:35+00:00         0        0      1            0  Allbirds
# 1  2022-09-27 17:24:40+00:00         0        1      0            0  Allbirds
# 2  2022-09-27 17:05:47+00:00         0        1      0            0  Allbirds
# 3  2022-09-26 21:01:50+00:00         0        1      1            0  Allbirds
# 4  2022-09-26 02:02:42+00:00         0        0      1            0  Allbirds
# ..                       ...       ...      ...    ...          ...       ...
# 71 2022-08-07 02:28:11+00:00         0        0      0            0  Allbirds
# 72 2022-08-05 18:31:50+00:00         0        0      1            0  Allbirds
# 73 2022-08-05 13:20:55+00:00         0        1      0            0  Allbirds
# 74 2022-08-04 11:25:58+00:00         0        0      0            0  Allbirds
# 75 2022-08-01 00:34:16+00:00         0        3      5            0  Allbirds
#
# [76 rows x 13 columns]

# %%
# Vans
vans_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'vans -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    vans_tweets.append(response)

# %%
result = []
user_dict = {}

for response in vans_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df5 = pd.DataFrame(result)
df5['brand'] = 'Vans'
df5
# Out:
#                 author_id         username  author_followers  author_tweets  \
# 0               411690904          bbynate               381          37470
# 1               320196121    PokeFanTrevor              1126          64697
# 2              3238131566     HulenHannahh               316          13034
# 3              3114994163    Holy_Coleyyyy               855          13454
# 4     1487020128826904576        DopeStilo              2381           4526
# ...                   ...              ...               ...            ...
# 1377            142895572          TJMattf              1040          93266
# 1378            142895572          TJMattf              1040          93266
# 1379  1216908853612359680       Jason77706                 9           2530
# 1380            181634813       buzyntexas              1250          58066
# 1381  1179102171985596416  SteveRi83474517               916           6082
#
#                                      author_description  \
# 0                            Pet owner and lover ♋️♐️♏️
# 1     Handheld Legend Affiliate - https://t.co/iG5wN...
# 2     24| mama | 6.14.17 | small business owner | NA...
# 3     We need perfection including serenity now & ev...
# 4     Singer🎤 Surfer 🌊 Producer🔊 Latin🦋 @StiloMusicG...
# ...                                                 ...
# 1377                                       #BellasFella
# 1378                                       #BellasFella
# 1379                                            Av Geek
# 1380  Everything Cowboys|🙏🏿 Believer|Grilled cheese ...
# 1381  Time flys day or night,\nevery tweet I read an...
#
#                      author_location  \
# 0                         Oxnard, CA
# 1                     Villa Rica, GA
# 2                       Arizona, USA
# 3                      Clarendon, TX
# 4                    California, USA
# ...                              ...
# 1377                 Minneapolis, MN
# 1378                 Minneapolis, MN
# 1379                            None
# 1380  Somewhere making it happen, TX
# 1381                   Cleveland, OH
#
#                                                    text  \
# 0     Do new vans cut up the back of everyone’s heel...
# 1     Got some new Vans for cheap 🥰🥰🥰 https://t.co/v...
# 2     Me: should i wear my vans in pictures?\nEm: do...
# 3     👍🏻✌️🕺💃♾! Vans on! Glam' song! Dance strong! Pr...
# 4     @Ms_Gekko @PrizemArtNft @MyCreativeOwls @HICee...
# ...                                                 ...
# 1377                         @allyallyallyaye Nice Vans
# 1378                            @texaschriss9 Nice Vans
# 1379  @LorenRuch @Hertz There are enough vans.  Just...
# 1380  It’s so common to see people sleepiness’s n th...
# 1381  @Magagal_ @AnnastasiaD4L I did this with my va...
#
#                     created_at  retweets  replies  likes  quote_count brand
# 0    2022-09-30 23:56:11+00:00         0        1      0            0  Vans
# 1    2022-09-30 23:45:39+00:00         0        1      6            0  Vans
# 2    2022-09-30 23:14:17+00:00         0        2      2            0  Vans
# 3    2022-09-30 23:09:34+00:00         0        0      2            0  Vans
# 4    2022-09-30 22:05:18+00:00         1        0      4            0  Vans
# ...                        ...       ...      ...    ...          ...   ...
# 1377 2022-08-01 02:30:33+00:00         0        0      0            0  Vans
# 1378 2022-08-01 02:11:29+00:00         0        0      0            0  Vans
# 1379 2022-08-01 02:03:54+00:00         0        0      0            0  Vans
# 1380 2022-08-01 01:04:10+00:00         0        0      0            0  Vans
# 1381 2022-08-01 00:16:01+00:00         0        0      2            0  Vans
#
# [1382 rows x 13 columns]

# %%
# Skechers
skechers_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'skechers -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    skechers_tweets.append(response)

# %%
result = []
user_dict = {}

for response in skechers_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df6 = pd.DataFrame(result)
df6['brand'] = 'Skechers'
df6
# Out:
#               author_id         username  author_followers  author_tweets  \
# 0            2320034306      _krownjules               398          26230
# 1            1249362884          _cdotT4               413           6254
# 2   1515776966208675850      Apizzle1800                15            352
# 3   1103385955661201408     run_marc_run               566           7995
# 4   1145466823422308353           eari_m               727          75534
# ..                  ...              ...               ...            ...
# 59  1554492930638745602         8102sdca                 0            197
# 60  1448339285074190338  EmilyMu38142215               947           9665
# 61  1251510910390337536  _RadicalReality              2470         181813
# 62            288570387       juliescloe               389           8360
# 63             17849182          cgperry               134           2627
#
#                                    author_description  \
# 0                     underrated is an understatement
# 1                   📍NJ //  IG: _c.t4 📸  \\ Cheyney U
# 2       #LLKP #4Evachukii 18💫💫 ATHLETE 🏀 5’9 c/o 2018
# 3                             Baseball, Beers, Bills.
# 4   I'm that elusive auto part that ur buddies tol...
# ..                                                ...
# 59                            It ends when it begins.
# 60  I'm an optimistic person with a sense of humou...
# 61  @KittyKatKeee @Rebeccahansonn @porcelain_yin @...
# 62                    I’d rather be in the mountains.
# 63
#
#              author_location  \
# 0   Jersey City, New YERRsey
# 1                       None
# 2                       None
# 3              Lancaster, NY
# 4    Sears Automotive U.S.A.
# ..                       ...
# 59                      None
# 60            Nashville, TN
# 61       PROTECTED BY MEGAN😍
# 62                       WPS
# 63                       NYC
#
#                                                  text  \
# 0   @jessy06961052 whichever one don’t got Skecher...
# 1   @Ty__215 @brittanyrennerr Skechers on here is ...
# 2   Shorty doooo not careee her ass got on Skecher...
# 3   @RockpileReport @Alf_Arteaga Fire all those Sk...
# 4   @omgitsbae10 @Crocs @WillDeas3 @lesmiller64 i ...
# ..                                                ...
# 59  Bought 2 pairs of Skechers shoes. Buy one get ...
# 60  @reevesyk1 @SKECHERS_UK I think you don't have...
# 61  Great to visit Skechers this morning. https://...
# 62  My husband is not allowed to wear Skechers gol...
# 63  @Skechers why have people take 20 mins to sign...
#
#                   created_at  retweets  replies  likes  quote_count     brand
# 0  2022-09-30 16:56:07+00:00         0        0      0            0  Skechers
# 1  2022-09-27 17:37:39+00:00         0        1      1            0  Skechers
# 2  2022-09-26 23:59:55+00:00         0        0      0            0  Skechers
# 3  2022-09-26 16:56:34+00:00         1        0      2            0  Skechers
# 4  2022-09-24 21:32:58+00:00         0        1      3            0  Skechers
# ..                       ...       ...      ...    ...          ...       ...
# 59 2022-08-05 00:26:01+00:00         0        0      0            0  Skechers
# 60 2022-08-04 14:53:55+00:00         0        0      1            0  Skechers
# 61 2022-08-02 15:38:58+00:00         0        0      0            0  Skechers
# 62 2022-08-02 00:30:54+00:00         0        0      3            0  Skechers
# 63 2022-08-01 18:39:05+00:00         0        0      0            0  Skechers
#
# [64 rows x 13 columns]

# %%
# Converse
converse_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'converse -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    converse_tweets.append(response)

# %%
result = []
user_dict = {}

for response in converse_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df7 = pd.DataFrame(result)
df7['brand'] = 'Converse'
df7
# Out:
#               author_id         username  author_followers  author_tweets  \
# 0              16274684  AuburnTgrMOates               650          18714
# 1             298020473     REMAXnorthSA               592           8387
# 2              23017444     tmj_sat_cler                91            898
# 3            1134851982        meetDTrav              1127          14750
# 4              22157813  tmj_sat_nursing               412            785
# ..                  ...              ...               ...            ...
# 941           539142424   NorthBeachDude                 6            304
# 942            36427341          __KJF55               907          45607
# 943           124081985      MiissBehave               377          27514
# 944  928741691510620160          jawilaa                39            572
# 945            22685659         kariroxx              7299          36309
#
#                                     author_description  \
# 0    He/Him. Who am I? No. Who are YOU? What are yo...
# 1
# 2    Follow this account for geo-targeted Office/Cl...
# 3    Booking agent and promotion member of B.O.M Bo...
# 4    Follow this account for geo-targeted Healthcar...
# ..                                                 ...
# 941
# 942                                         Detroit...
# 943
# 944                                 coach pussy slayer
# 945  📍 Long Beach, CA #Lakers #Dodgers #RamsHouse #...
#
#                     author_location  \
# 0                 Columbus, Georgia
# 1    8131 W Hausman, San Antonio TX
# 2                   San Antonio, TX
# 3                    Columbus, Ohio
# 4                   San Antonio, TX
# ..                              ...
# 941              Massachusetts, USA
# 942                         Detroit
# 943                   Manhattan, NY
# 944             North Carolina, USA
# 945                            None
#
#                                                   text  \
# 0    @_brooklynsummer @RobertLeveyII @jahsim346 @Co...
# 1    See a virtual tour of one of our newest #listi...
# 2    Can you recommend anyone for this Admin/Secret...
# 3    @emann28210 @shaqwitnobricks @JAYALNOCAP Good ...
# 4    Want to land a job like "Patient Care Technici...
# ..                                                 ...
# 941  Think about this sports fans when talking abou...
# 942  Chillin' out on this patio... I'm just glad I ...
# 943  Once the mind is made up, there’s no need to f...
# 944                       @jiawnah me with my converse
# 945  Converse weren’t just made for playing basketb...
#
#                    created_at  retweets  replies  likes  quote_count     brand
# 0   2022-09-30 21:10:37+00:00         0        0      1            0  Converse
# 1   2022-09-30 21:04:13+00:00         0        0      0            0  Converse
# 2   2022-09-30 20:24:25+00:00         0        0      0            0  Converse
# 3   2022-09-30 19:19:45+00:00         0        2      0            0  Converse
# 4   2022-09-30 17:59:02+00:00         0        0      0            0  Converse
# ..                        ...       ...      ...    ...          ...       ...
# 941 2022-08-01 15:33:05+00:00         0        0      0            0  Converse
# 942 2022-08-01 06:23:20+00:00         0        0      0            0  Converse
# 943 2022-08-01 03:31:06+00:00         0        0      1            0  Converse
# 944 2022-08-01 02:17:56+00:00         0        0      0            0  Converse
# 945 2022-08-01 01:28:14+00:00         2       15    202            1  Converse
#
# [946 rows x 13 columns]

# %%
# Reebok
reebok_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'reebok -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    reebok_tweets.append(response)

# %%
result = []
user_dict = {}

for response in reebok_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df8 = pd.DataFrame(result)
df8['brand'] = 'Reebok'
df8
# Out:
#                author_id         username  author_followers  author_tweets  \
# 0               21984092    cristinavanko              5696          35234
# 1    1574967030331199497  DiannaJ71861947                 1              8
# 2     797161473382502400   scrmblnscholar               309          26451
# 3     797161473382502400   scrmblnscholar               309          26451
# 4              576574220  BurtonGuster216              1384          23220
# ..                   ...              ...               ...            ...
# 241   775916651187351553    The_Han_Br0lo               157           9389
# 242           2918955818  marcelobalboa17             11307           3941
# 243             19039664       linnynicks               300          11476
# 244            105267482  ItzMrBlunt2Yall             15135         198393
# 245             37935188          say_blk              4050         176438
#
#                                     author_description  \
# 0    building @datewitharrow audio dating 🏹 acd art...
# 1    Black YouTuber using my real name this year my...
# 2    My life is a play. Addicted to hoops. Sneakerh...
# 3    My life is a play. Addicted to hoops. Sneakerh...
# 4    Just ask me to elaborate my thoughts. Please. ...
# ..                                                 ...
# 241  I’m Rene. I throw baseballs and occasionally h...
# 242  Official Twitter of Marcelo Balboa USMNT Membe...
# 243                                     bring the data
# 244  I’m going to talk a lot of shit you’re not goi...
# 245
#
#             author_location  \
# 0              New York, NY
# 1             United States
# 2                      None
# 3                      None
# 4               Chicago, IL
# ..                      ...
# 241             Phoenix, AZ
# 242                    None
# 243                   phila
# 244  San Diego, California
# 245             Houston, TX
#
#                                                   text  \
# 0    @jemgold_ ariats are comfy and cute (reebok so...
# 1        @iamcardib @Reebok Please do a color in lime.
# 2               @TheDoddJD Reebok ones don't count lol
# 3    The Reebok game worn authentics from the final...
# 4    Hot take…. People sleep on Reebok products. Qu...
# ..                                                 ...
# 241  Armpit musty, Reebok crusty https://t.co/KjJ3z...
# 242  @DoubleOhNegatve I believe that was the Reebok...
# 243  If you ever find yourself talking shit on will...
# 244  Think the 4,5 shoes gon be Reebok, Doc’s and s...
# 245  🔥 It is back to school shopping time and what ...
#
#                    created_at  retweets  replies  likes  quote_count   brand
# 0   2022-09-30 18:11:34+00:00         0        2      1            0  Reebok
# 1   2022-09-30 17:32:43+00:00         0        0      0            0  Reebok
# 2   2022-09-30 16:19:03+00:00         0        0      0            0  Reebok
# 3   2022-09-30 16:00:55+00:00         3        2     18            0  Reebok
# 4   2022-09-30 03:44:48+00:00         0        2      2            0  Reebok
# ..                        ...       ...      ...    ...          ...     ...
# 241 2022-08-02 20:12:31+00:00         0        0      1            1  Reebok
# 242 2022-08-02 04:52:46+00:00         0        1      1            0  Reebok
# 243 2022-08-02 00:43:42+00:00         0        0      2            0  Reebok
# 244 2022-08-01 18:19:04+00:00         0        0      0            0  Reebok
# 245 2022-08-01 13:30:07+00:00         7        1     12            1  Reebok
#
# [246 rows x 13 columns]

# %%
# Under Armour
ua_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'under armour -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    ua_tweets.append(response)

# %%
result = []
user_dict = {}

for response in ua_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df9 = pd.DataFrame(result)
df9['brand'] = 'Under Armour'
df9
# Out:
#                author_id         username  author_followers  author_tweets  \
# 0    1045871486299492352     itsjacieeeee               303           3580
# 1               41874604      ChicagoMT22               106           6055
# 2               26148614      danielfheck              2765          19386
# 3    1023258741741940736  AaronMoldenhau1                83           1502
# 4    1407725815345917952    StarsNash_MBB              1305           1733
# ..                   ...              ...               ...            ...
# 166           1873452596        a_luevano               967          16402
# 167  1474403171082674221     saharaw_2025               450             93
# 168            146716348    okinfortworth              3247          38147
# 169  1145893268439236608    WaybrightAdam               558           4503
# 170  1233540039524716545     Diesel_Crush               652          57114
#
#                                     author_description  author_location  \
# 0     Be original 💞 God first ❤️Cardiovascular tech 🫀🫁   Las Cruces, NM
# 1    Family man, father, consultant, and part time ...      Chicago, IL
# 2    Assistant AD of Marketing, @AuburnTigers | @it...       Auburn, AL
# 3                              https://t.co/M15XbVItVn    Iron ridge wi
# 4    STARS Basketball Club powered by Under Armour....    Nashville, TN
# ..                                                 ...              ...
# 166    Sports Director @23ABCNews - @Fresno_State Alum  Bakersfield, CA
# 167  4.3 GPA | Slapper/Power Hitter | CF | H2F 2.56...  Wake Forest, NC
# 168  God is good ALL the time! Love 🇺🇸 🎣 BASS LIFE ...     Arlington TX
# 169                                                           Worldwide
# 170  Army Vet, Whiskey drinking, soul food eating, ...  New Orleans, LA
#
#                                                   text  \
# 0    My biggest win is being able to wear XL in kid...
# 1    @Joeingram1 She wasn't even wearing her Under ...
# 2    Evan McPherson 🤝  AU Team Shop  \n\nReminder t...
# 3    Check out Wisconsin Badgers Under Armour Women...
# 4    It was another great week at the STARS High Sc...
# ..                                                 ...
# 166  It’s official: CSU Bakersfield and Under Armou...
# 167  STARZ MADE SOME NOISE TODAY! Got the opportuni...
# 168  @AndrewNemec @DJ2g23 “Hicks has a lot of time ...
# 169  CSU Bakersfield Athletics will announce a new ...
# 170  Nike, Under Armour, Samsung https://t.co/EePpY...
#
#                    created_at  retweets  replies  likes  quote_count  \
# 0   2022-09-30 11:22:56+00:00         0        0      4            0
# 1   2022-09-30 03:41:58+00:00         0        0      2            0
# 2   2022-09-30 03:22:21+00:00         0        0      4            0
# 3   2022-09-29 18:16:01+00:00         0        0      0            0
# 4   2022-09-29 16:57:16+00:00         2        0      8            0
# ..                        ...       ...      ...    ...          ...
# 166 2022-08-02 18:27:28+00:00         5        0     27            1
# 167 2022-08-02 02:06:23+00:00         3        3     48            2
# 168 2022-08-02 01:08:24+00:00         0        0      2            0
# 169 2022-08-01 22:52:41+00:00         2        2      7            0
# 170 2022-08-01 19:11:59+00:00         0        0      0            0
#
#             brand
# 0    Under Armour
# 1    Under Armour
# 2    Under Armour
# 3    Under Armour
# 4    Under Armour
# ..            ...
# 166  Under Armour
# 167  Under Armour
# 168  Under Armour
# 169  Under Armour
# 170  Under Armour
#
# [171 rows x 13 columns]

# %%
# New Balance
nb_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'new balance -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    nb_tweets.append(response)

# %%
result = []
user_dict = {}

for response in nb_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df10 = pd.DataFrame(result)
df10['brand'] = 'New Balance'
df10
# Out:
#                author_id         username  author_followers  author_tweets  \
# 0             2939996287         253Coble                52           1202
# 1               48419856     stuartpalley             22730          52040
# 2    1357847875477241857       kevin_ny_9                95            131
# 3               77118134          batesbn              2031           4151
# 4              112921508  ChaseStackwells               842          75086
# ..                   ...              ...               ...            ...
# 661             39148101       EmilyFurda               578          35532
# 662           1909661978     RaymondGill_               717          18670
# 663            261714969       Saenthegod               726          51120
# 664            249988680        _surfresh              2566         153575
# 665             41593115  iamscottenglish              3189           8538
#
#                                     author_description    author_location  \
# 0                   Father, husband, sneakerhead, etc.         Tacoma, WA
# 1    Photographer, writer, maker | Into The Inferno...   Acjachemen Land
# 2                                    Based in New York         Queens, NY
# 3    #Author #FreelanceWriter #Journalist in #Cleve...          Cleveland
# 4    Sneaker Connoisseur, Big Steppa, Cultured Indi...        Houston, TX
# ..                                                 ...                ...
# 661  Blogger, writer, editor. Jesus follower. Pengu...      Johnstown, Pa
# 662                                                     Fort Worth, Texas
# 663                        half hurricane half volcano               None
# 664                                     Photographer 📸         Dallas, TX
# 665  Political has been turned philatelist. Interna...     Bellefonte, PA
#
#                                                   text  \
# 0    @sockjig Really hope it isn’t the end he’s suc...
# 1            And no New Balance 501s are NOT an option
# 2    Kith for New Balance \nFall2 2022 https://t.co...
# 3    Excited to hear @kkellyhancock @MAGNETOhio @Ne...
# 4    I'm going to have 5 pairs of New Balance in my...
# ..                                                 ...
# 661  @Local12Kathryn 2 new pairs of New Balance for...
# 662  First day of a new month. Always be bold and l...
# 663  “New balance sneakerssssss “ haha I got the va...
# 664  I’ve enjoyed all the new music that’s dropped ...
# 665  @DigiPhilatelist @CollectsStamps @virtuafil Th...
#
#                    created_at  retweets  replies  likes  quote_count  \
# 0   2022-09-30 20:24:54+00:00         0        1      1            0
# 1   2022-09-30 20:10:28+00:00         0        1      5            0
# 2   2022-09-30 19:15:27+00:00         0        0     45            0
# 3   2022-09-30 16:19:48+00:00         2        0      2            0
# 4   2022-09-30 15:48:21+00:00         0        0      0            0
# ..                        ...       ...      ...    ...          ...
# 661 2022-08-01 10:25:13+00:00         0        0      0            0
# 662 2022-08-01 10:19:18+00:00         0        0      2            0
# 663 2022-08-01 09:19:50+00:00         0        0      0            0
# 664 2022-08-01 02:22:19+00:00         1        2      1            0
# 665 2022-08-01 01:43:37+00:00         0        1      3            0
#
#            brand
# 0    New Balance
# 1    New Balance
# 2    New Balance
# 3    New Balance
# 4    New Balance
# ..           ...
# 661  New Balance
# 662  New Balance
# 663  New Balance
# 664  New Balance
# 665  New Balance
#
# [666 rows x 13 columns]

# %%
# Adidas
adidas_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'adidas -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    adidas_tweets.append(response)

# %%
result = []
user_dict = {}

for response in adidas_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df11 = pd.DataFrame(result)
df11['brand'] = 'Adidas'
df11
# Out:
#                 author_id         username  author_followers  author_tweets  \
# 0                85966951       deftones4u                64            290
# 1     1247183624425930753     TeamLexHoops               895            120
# 2                71125241    VillageSoccer               357           1732
# 3               788291030    abdulla_12_92               703           9724
# 4     1178740207375519744       ManriqueTj             10244          28843
# ...                   ...              ...               ...            ...
# 2345  1535065371874566151  goodhairgardner                19             50
# 2346  1504474595650273283      7795Specter                 1            283
# 2347            461627703         macburgz              3660          66292
# 2348            461627703         macburgz              3660          66292
# 2349   948340326737072128  Walk_Off_Sports              5843           7662
#
#                                      author_description      author_location  \
# 0                                                                       None
# 1     Select girls' basketball club named after WNBA...           Texas, USA
# 2                           A Soccer & Lifestyle Joint.  Tarrytown, New York
# 3     #Football, #Basketball and #Baseball Guy 🏈🏀⚾️....         New York, NY
# 4     I write SciFi, horror & other books. My debut ...                 None
# ...                                                 ...                  ...
# 2345                            #MaskUp #VaxUp #BIDEN24           Everywhere
# 2346                                                           Westfield, MA
# 2347                              outside trynna endure      Lemon Grove, CA
# 2348                              outside trynna endure      Lemon Grove, CA
# 2349  •Perfect Game USA Affiliate Partner •Future HQ...           Texas, USA
#
#                                                    text  \
# 0     @SouthPark @adidas I need a replacement pair! ...
# 1     Team Lex Nation would like to congratulate McK...
# 2     Pure 🇺🇸 Beauty.\n#vssvintage\n#ussoccer\n#adid...
# 3     Need these 🔥. @adidas @PatrickMahomes #adidas ...
# 4     @thanightskyy03 Yes they are. There's a place ...
# ...                                                 ...
# 2345  As an unbiased youth sports fan. I am once aga...
# 2346                      I like Adidas,  nice company.
# 2347                Just never buy adidas shoes anymore
# 2348  Sometimes I wanna wear my adidas sweatpants wi...
# 2349  Adidas Titans-John Ramsey launches a double to...
#
#                     created_at  retweets  replies  likes  quote_count   brand
# 0    2022-09-30 23:29:16+00:00         0        0      0            0  Adidas
# 1    2022-09-30 23:07:19+00:00         8        1     53            1  Adidas
# 2    2022-09-30 22:10:45+00:00         0        0      0            0  Adidas
# 3    2022-09-30 20:50:41+00:00         0        0      0            0  Adidas
# 4    2022-09-30 20:16:14+00:00         0        0      0            0  Adidas
# ...                        ...       ...      ...    ...          ...     ...
# 2345 2022-08-01 01:32:25+00:00         0        2      1            0  Adidas
# 2346 2022-08-01 01:09:12+00:00         0        0      0            0  Adidas
# 2347 2022-08-01 01:00:19+00:00         0        0      0            0  Adidas
# 2348 2022-08-01 00:59:57+00:00         0        1      4            0  Adidas
# 2349 2022-08-01 00:10:04+00:00         3        1      9            1  Adidas
#
# [2350 rows x 13 columns]

# %%
# Nike
nike_tweets = []
for response in tweepy.Paginator(client.search_all_tweets, 
                                 query = 'nike -is:retweet lang:en place_country:US',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-08-01T00:00:00Z',
                                 end_time = '2022-09-30T23:59:59Z',
                                 max_results=500, limit = 20):
    time.sleep(1)
    nike_tweets.append(response)

# %%
result = []
user_dict = {}

for response in nike_tweets:

    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:

        author_info = user_dict[tweet.author_id]

        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_followers': author_info['followers'],
                       'author_tweets': author_info['tweets'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'likes': tweet.public_metrics['like_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })


df12 = pd.DataFrame(result)
df12['brand'] = 'Nike'
df12
# Out:
#                 author_id         username  author_followers  author_tweets  \
# 0                87144412     GarrettKGray               370          12033
# 1               492330913   LockDown_Lopes               459          97476
# 2                37706001      RyanGensler              6679          13596
# 3                17417435       ShellzBoss               563          22062
# 4      853714067692806144        DJKingJam               319           3116
# ...                   ...              ...               ...            ...
# 7890             40580353         JBlock49              4223         143775
# 7891  1515614465097568258        babydevoh                15            206
# 7892  1307302810019491841  ifquinnhadagram               400          16507
# 7893           1692907934          imwawit                16           2986
# 7894             23896893        MissSneed              4100         303841
#
#                                      author_description      author_location  \
# 0     Land Economist & Economic Development Speciali...         Coos Bay, OR
# 1     @nicekicks, sports, & memes | University of Ar...       Scottsdale, AZ
# 2     315 Born and Raised: Assistant Basketball Coac...        Champaign, IL
# 3     #TeamLibra #TeamLesbian Hibernating, should be...  Maryland, Michigan
# 4     Jordan Shoe collector || DJ Jamez || Music Pro...          Seattle, WA
# ...                                                 ...                  ...
# 7890  total football surrogate // team site coverage...         Portland, OR
# 7891                                 the angry Aries ♈️                 None
# 7892  ❤️ 👶🏼Quinn.Oregon’04 via LA.❤️=🔋&🔋is everythin...      Los Angeles, CA
# 7893  It's not easy to be me. I wasn't a good boy at...               NY, NY
# 7894  forever on some fly shit. ✈️ don’t take me ser...         Dallas, TX 📍
#
#                                                    text  \
# 0     @ShaneDaleAZ Totally. The Nike uniforms since ...
# 1     Hats off to Tom Sachs and the marketing team a...
# 2     The look on @makiracook face! 😂 \n\nThanks @Ni...
# 3     Check out my new pickup from Nike⁠ SNKRS: http...
# 4     @jameslfreelance @Jumpman23 @Nike @nikestore O...
# ...                                                 ...
# 7890  i wonder how many sports bras chloe kelly sold...
# 7891                     Hiked the nike hill today🏃‍♂️✅
# 7892                   @WTDduckss @Nike Yes yes and yes
# 7893                 @GracezyUchi @Nike Thanks Bunso ❤️
# 7894  @StewardessChick me either 😭😭 i just remember ...
#
#                     created_at  retweets  replies  likes  quote_count brand
# 0    2022-09-30 23:46:59+00:00         0        0      0            0  Nike
# 1    2022-09-30 23:43:45+00:00         0        0      0            0  Nike
# 2    2022-09-30 23:38:15+00:00         1        1     23            0  Nike
# 3    2022-09-30 23:35:28+00:00         0        1      0            0  Nike
# 4    2022-09-30 23:15:57+00:00         0        0      2            0  Nike
# ...                        ...       ...      ...    ...          ...   ...
# 7890 2022-08-01 00:42:17+00:00         2        0      4            0  Nike
# 7891 2022-08-01 00:18:54+00:00         0        0      0            0  Nike
# 7892 2022-08-01 00:05:11+00:00         0        0      0            0  Nike
# 7893 2022-08-01 00:03:14+00:00         0        0      0            0  Nike
# 7894 2022-08-01 00:02:07+00:00         0        1      0            0  Nike
#
# [7895 rows x 13 columns]

# %%
df_concat = pd.concat([df, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])

# %%
df_concat
# Out:
#                 author_id         username  author_followers  author_tweets  \
# 0     1549441622231900164     SuchitaHedau               353           1465
# 1      997270922976481282     JEFF_SON_334               606           3780
# 2                69133413    tarsismenezes               391          34992
# 3               508551405  My_business_man               663          18657
# 4                66769124    THIAGAOAGUIAR              1530          49626
# ...                   ...              ...               ...            ...
# 7890             40580353         JBlock49              4223         143775
# 7891  1515614465097568258        babydevoh                15            206
# 7892  1307302810019491841  ifquinnhadagram               400          16507
# 7893           1692907934          imwawit                16           2986
# 7894             23896893        MissSneed              4100         303841
#
#                                      author_description     author_location  \
# 0                                                                      None
# 1     Husband, Father to a son ,COOL MF in General U...      Montgomery, AL
# 2                                              BBBholic     Los Angeles, CA
# 3     This life is 100% your responsibility, so know...  Free in the World
# 4     Paulistano , Sobrevivente ! Enquanto meu coraç...       Weehawken, NJ
# ...                                                 ...                 ...
# 7890  total football surrogate // team site coverage...        Portland, OR
# 7891                                 the angry Aries ♈️                None
# 7892  ❤️ 👶🏼Quinn.Oregon’04 via LA.❤️=🔋&🔋is everythin...     Los Angeles, CA
# 7893  It's not easy to be me. I wasn't a good boy at...              NY, NY
# 7894  forever on some fly shit. ✈️ don’t take me ser...        Dallas, TX 📍
#
#                                                    text  \
# 0                           @kuchbhishubhh Puma shoes 😮
# 1     I hate the fact that Puma ain’t got no sneaker...
# 2     @slashviolence @PUMA @neymarjr @pumafootball Y...
# 3     @i95Bully @ForeverKnicks_ Nah. Puma store on 4...
# 4     Extremely disappointed PUMA . The LGBTQA+ suff...
# ...                                                 ...
# 7890  i wonder how many sports bras chloe kelly sold...
# 7891                     Hiked the nike hill today🏃‍♂️✅
# 7892                   @WTDduckss @Nike Yes yes and yes
# 7893                 @GracezyUchi @Nike Thanks Bunso ❤️
# 7894  @StewardessChick me either 😭😭 i just remember ...
#
#                     created_at  retweets  replies  likes  quote_count brand
# 0    2022-09-30 23:59:39+00:00         0        0      1            0  Puma
# 1    2022-09-30 22:36:38+00:00         0        0      0            0  Puma
# 2    2022-09-30 22:05:04+00:00         0        0      0            0  Puma
# 3    2022-09-30 17:33:24+00:00         0        1      1            0  Puma
# 4    2022-09-30 16:08:20+00:00         0        0      3            0  Puma
# ...                        ...       ...      ...    ...          ...   ...
# 7890 2022-08-01 00:42:17+00:00         2        0      4            0  Nike
# 7891 2022-08-01 00:18:54+00:00         0        0      0            0  Nike
# 7892 2022-08-01 00:05:11+00:00         0        0      0            0  Nike
# 7893 2022-08-01 00:03:14+00:00         0        0      0            0  Nike
# 7894 2022-08-01 00:02:07+00:00         0        1      0            0  Nike
#
# [15275 rows x 13 columns]

# %%
df_concat.to_csv('brands_franyang_oct1.csv')
